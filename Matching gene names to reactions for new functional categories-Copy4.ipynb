# %%
import numpy as np
import pandas as pd
import cobra.test
import os
from os.path import join

from time import time

a= cobra.io.read_sbml_model("iEC1344_C.xml")

# %%
i= -1

J=list()
C=list()
J.append(a.genes[0].name)
C.append(a.genes[0].reactions)

dictionary = dict(zip(J, C))

dictionary
# Out:
# {'PhoE': frozenset({<Reaction 12PPDRtex at 0x7fbe2bf9bc10>,
#             <Reaction 12PPDStex at 0x7fbe2bf9bca0>,
#             <Reaction 23CAMPtex at 0x7fbe2bf9bfd0>,
#             <Reaction 23CCMPtex at 0x7fbe2bf9bdc0>,
#             <Reaction 23CGMPtex at 0x7fbe2bfaa460>,
#             <Reaction 23CUMPtex at 0x7fbe2bf9b910>,
#             <Reaction 23DAPPAtex at 0x7fbe2bf9b970>,
#             <Reaction 26DAHtex at 0x7fbe2bfb88e0>,
#             <Reaction 34dhpactex at 0x7fbe2bf73ee0>,
#             <Reaction 3AMPtex at 0x7fbe2bf73f70>,
#             <Reaction 3CMPtex at 0x7fbe2bf73b50>,
#             <Reaction 3GMPtex at 0x7fbe2bf73f10>,
#             <Reaction 3HPPtex at 0x7fbe2bf0fd60>,
#             <Reaction 3PEPTtex at 0x7fbe2bee1b50>,
#             <Reaction 3UMPtex at 0x7fbe2bee1dc0>,
#             <Reaction 3hoxpactex at 0x7fbe2b021c10>,
#             <Reaction 4HOXPACDtex at 0x7fbe2bef08e0>,
#             <Reaction 4PEPTtex at 0x7fbe2befef70>,
#             <Reaction 4hoxpactex at 0x7fbe2b021cd0>,
#             <Reaction 5DGLCNtex at 0x7fbe2be8c520>,
#             <Reaction 5MTRtex at 0x7fbe2be8cf70>,
#             <Reaction 6APAt1 at 0x7fbe2b036820>,
#             <Reaction ABUTtex at 0x7fbe2bf1bf40>,
#             <Reaction ACACtex at 0x7fbe2bf37fa0>,
#             <Reaction ACALDtex at 0x7fbe2bec7b50>,
#             <Reaction ACGAL1Ptex at 0x7fbe2bec7f70>,
#             <Reaction ACGALtex at 0x7fbe2bee1a60>,
#             <Reaction ACGAM1Ptex at 0x7fbe2bee1fd0>,
#             <Reaction ACGAtex at 0x7fbe2bef0eb0>,
#             <Reaction ACMANAtex at 0x7fbe2befef10>,
#             <Reaction ACMUMtex at 0x7fbe2be8ce80>,
#             <Reaction ACSERtex at 0x7fbe2beb6d60>,
#             <Reaction ACtex at 0x7fbe2be56c40>,
#             <Reaction ADEtex at 0x7fbe2be64e80>,
#             <Reaction AGMtex at 0x7fbe2bdd4e80>,
#             <Reaction AKGtex at 0x7fbe2be47f10>,
#             <Reaction ALAALAtex at 0x7fbe2beb6730>,
#             <Reaction ALAtex at 0x7fbe2be74f10>,
#             <Reaction ALLTNtex at 0x7fbe2be23670>,
#             <Reaction ALLtex at 0x7fbe2be34c10>,
#             <Reaction AMPtex at 0x7fbe2bde3ee0>,
#             <Reaction ANHGMtex at 0x7fbe2bde3970>,
#             <Reaction ARBTtex at 0x7fbe2bc5ba90>,
#             <Reaction ARBtex at 0x7fbe2bc1ef10>,
#             <Reaction ARGtex at 0x7fbe2bb63eb0>,
#             <Reaction ASCBtex at 0x7fbe2bb1bb80>,
#             <Reaction ASNtex at 0x7fbe2ba5cdc0>,
#             <Reaction ASO3tex at 0x7fbe2ba03670>,
#             <Reaction ASPtex at 0x7fbe2bde3c70>,
#             <Reaction BALAtex at 0x7fbe2bd93fa0>,
#             <Reaction BTNtex at 0x7fbe2bda3f40>,
#             <Reaction BUTSO3tex at 0x7fbe2bdb2580>,
#             <Reaction BUTtex at 0x7fbe2bd52f70>,
#             <Reaction CA2tex at 0x7fbe2bd5ecd0>,
#             <Reaction CD2tex at 0x7fbe2bd10910>,
#             <Reaction CGLYtex at 0x7fbe2bda3fa0>,
#             <Reaction CHLtex at 0x7fbe2bda3f10>,
#             <Reaction CHTBStex at 0x7fbe2bdbeca0>,
#             <Reaction CITtex at 0x7fbe2bdbee20>,
#             <Reaction CLBtex at 0x7fbe2b060ee0>,
#             <Reaction CLtex at 0x7fbe2bd7efd0>,
#             <Reaction CMPtex at 0x7fbe2bd7ef70>,
#             <Reaction CMtex at 0x7fbe2bd6caf0>,
#             <Reaction CO2tex at 0x7fbe2bd10f40>,
#             <Reaction COBALT2tex at 0x7fbe2bd1fd30>,
#             <Reaction CRNDtex at 0x7fbe2bcd0d00>,
#             <Reaction CRNtex at 0x7fbe2bcdeb20>,
#             <Reaction CSNtex at 0x7fbe2bcefdf0>,
#             <Reaction CU2tex at 0x7fbe2bc8de80>,
#             <Reaction CUtex at 0x7fbe2bc9eaf0>,
#             <Reaction CYANtex at 0x7fbe2bc9ed60>,
#             <Reaction CYNTtex at 0x7fbe2bcadc70>,
#             <Reaction CYSDtex at 0x7fbe2bcaddc0>,
#             <Reaction CYStex at 0x7fbe2bc4cdc0>,
#             <Reaction CYTDtex at 0x7fbe2bc5be50>,
#             <Reaction DALAtex at 0x7fbe2bcd0c40>,
#             <Reaction DAMPtex at 0x7fbe2bcefe20>,
#             <Reaction DAPtex at 0x7fbe2bcfefd0>,
#             <Reaction DARBtex at 0x7fbe2af6bdc0>,
#             <Reaction DCAtex at 0x7fbe2bc9ebb0>,
#             <Reaction DCMPtex at 0x7fbe2bc9ea90>,
#             <Reaction DDGLCNtex at 0x7fbe2bcad8e0>,
#             <Reaction DGMPtex at 0x7fbe2bcbcd60>,
#             <Reaction DGSNtex at 0x7fbe2bc4cc70>,
#             <Reaction DHAtex at 0x7fbe2bc5bca0>,
#             <Reaction DIMPtex at 0x7fbe2bc0af40>,
#             <Reaction DINStex at 0x7fbe2bc6ca60>,
#             <Reaction DMSOtex at 0x7fbe2bc33e80>,
#             <Reaction DMStex at 0x7fbe2bc33a30>,
#             <Reaction DOPAtex at 0x7fbe2bbc6eb0>,
#             <Reaction DOXRBCNtex at 0x7fbe2bbc6f10>,
#             <Reaction DSERtex at 0x7fbe2bbea7c0>,
#             <Reaction DTMPtex at 0x7fbe2bbfed90>,
#             <Reaction DUMPtex at 0x7fbe2bbfeaf0>,
#             <Reaction D_LACtex at 0x7fbe2bc7bdc0>,
#             <Reaction ETHAtex at 0x7fbe2bb92ee0>,
#             <Reaction ETHSO3tex at 0x7fbe2bb50dc0>,
#             <Reaction ETOHtex at 0x7fbe2bbfefd0>,
#             <Reaction F6Ptex at 0x7fbe2bb63c10>,
#             <Reaction FALDtex at 0x7fbe2bb1bf10>,
#             <Reaction FE2tex at 0x7fbe2bae8fa0>,
#             <Reaction FE3tex at 0x7fbe2bab5d00>,
#             <Reaction FORtex at 0x7fbe2baa3d90>,
#             <Reaction FRULYStex at 0x7fbe2ba49a60>,
#             <Reaction FRUURtex at 0x7fbe2ba49d90>,
#             <Reaction FRUtex at 0x7fbe2ba5cdf0>,
#             <Reaction FUCtex at 0x7fbe2ba5c8e0>,
#             <Reaction FUMtex at 0x7fbe2ba6de80>,
#             <Reaction FUSAtex at 0x7fbe2ba6dfa0>,
#             <Reaction G1Ptex at 0x7fbe2ba16eb0>,
#             <Reaction G3PCtex at 0x7fbe2ba16ee0>,
#             <Reaction G3PEtex at 0x7fbe2ba28d90>,
#             <Reaction G3PGtex at 0x7fbe31783a60>,
#             <Reaction G3PItex at 0x7fbe3179c5b0>,
#             <Reaction G3PStex at 0x7fbe3179c280>,
#             <Reaction G6Ptex at 0x7fbe31753e50>,
#             <Reaction GAL1Ptex at 0x7fbe3176ba90>,
#             <Reaction GALAMtex at 0x7fbe2b00b5e0>,
#             <Reaction GALBDtex at 0x7fbe31735eb0>,
#             <Reaction GALCTNLtex at 0x7fbe31778130>,
#             <Reaction GALCTNtex at 0x7fbe31699850>,
#             <Reaction GALCTtex at 0x7fbe31692c70>,
#             <Reaction GALTtex at 0x7fbe31699c40>,
#             <Reaction GALURtex at 0x7fbe316e7f70>,
#             <Reaction GALtex at 0x7fbe308bb250>,
#             <Reaction GAMAN6Ptex at 0x7fbe308c4fd0>,
#             <Reaction GAMtex at 0x7fbe30931160>,
#             <Reaction GBBTNtex at 0x7fbe30881b50>,
#             <Reaction GDPtex at 0x7fbe30839e80>,
#             <Reaction GLCNtex at 0x7fbe3172e5e0>,
#             <Reaction GLCRtex at 0x7fbe316cf370>,
#             <Reaction GLCUR1Ptex at 0x7fbe316eeee0>,
#             <Reaction GLCURtex at 0x7fbe316a2550>,
#             <Reaction GLCtex_copy1 at 0x7fbe31760790>,
#             <Reaction GLNtex at 0x7fbe308cfeb0>,
#             <Reaction GLUtex at 0x7fbe308afcd0>,
#             <Reaction GLYALDtex at 0x7fbe30857f10>,
#             <Reaction GLYBtex at 0x7fbe30367820>,
#             <Reaction GLYC2Ptex at 0x7fbe3088ca00>,
#             <Reaction GLYC3Ptex at 0x7fbe3315c160>,
#             <Reaction GLYCAtex at 0x7fbe308c4d60>,
#             <Reaction GLYCLTtex at 0x7fbe2b8ce610>,
#             <Reaction GLYCtex at 0x7fbe2b846eb0>,
#             <Reaction GLYtex at 0x7fbe2b7eabb0>,
#             <Reaction GMPtex at 0x7fbe2b71bbb0>,
#             <Reaction GSNtex at 0x7fbe2b5decd0>,
#             <Reaction GTHOXtex at 0x7fbe2b59eeb0>,
#             <Reaction GTHRDtex at 0x7fbe2b508f10>,
#             <Reaction GTPtex at 0x7fbe2b49dd60>,
#             <Reaction H2O2tex at 0x7fbe2ba3b4f0>,
#             <Reaction H2Otex at 0x7fbe2b9235e0>,
#             <Reaction H2Stex at 0x7fbe2b937ee0>,
#             <Reaction H2tex at 0x7fbe2b937370>,
#             <Reaction HCINNMtex at 0x7fbe2b8f6e20>,
#             <Reaction HG2tex at 0x7fbe2b8a9eb0>,
#             <Reaction HIStex at 0x7fbe2b846880>,
#             <Reaction HOMtex at 0x7fbe2b878f40>,
#             <Reaction HPPPNtex at 0x7fbe2b86fd60>,
#             <Reaction HXAtex at 0x7fbe3086d940>,
#             <Reaction HYXNtex at 0x7fbe2b8ceee0>,
#             <Reaction Htex at 0x7fbe2b937f40>,
#             <Reaction IDONtex at 0x7fbe2b8a09d0>,
#             <Reaction ILEtex at 0x7fbe2b8b2820>,
#             <Reaction IMPtex at 0x7fbe2b8bb850>,
#             <Reaction INDOLEtex at 0x7fbe2b864640>,
#             <Reaction INSTtex at 0x7fbe2b84ed00>,
#             <Reaction ISETACtex at 0x7fbe2b81daf0>,
#             <Reaction Ktex at 0x7fbe2b7c3eb0>,
#             <Reaction LALADGLUtex at 0x7fbe2b7eaf10>,
#             <Reaction LALALGLUtex at 0x7fbe2b7ea880>,
#             <Reaction LCTStex at 0x7fbe2b7feee0>,
#             <Reaction LEUtex at 0x7fbe2b7a5e50>,
#             <Reaction LIPOtex at 0x7fbe2b74bf40>,
#             <Reaction LYStex at 0x7fbe2b7749a0>,
#             <Reaction LYXtex at 0x7fbe2b707b80>,
#             <Reaction L_LACtex_copy1 at 0x7fbe2b7d6ee0>,
#             <Reaction L_LACtex_copy2 at 0x7fbe2b0b7cd0>,
#             <Reaction MALDtex at 0x7fbe2b707f40>,
#             <Reaction MALtex at 0x7fbe2b6c4fd0>,
#             <Reaction MAN6Ptex at 0x7fbe2b6d8a60>,
#             <Reaction MANGLYCtex at 0x7fbe2b71bd00>,
#             <Reaction MANtex at 0x7fbe2b730f70>,
#             <Reaction MELIBtex at 0x7fbe2b6ebfd0>,
#             <Reaction MEOHtex at 0x7fbe2b6fdd60>,
#             <Reaction METDtex at 0x7fbe2b6a9b50>,
#             <Reaction METSOX1tex at 0x7fbe2b6a9be0>,
#             <Reaction METSOX2tex at 0x7fbe2b6a9d90>,
#             <Reaction METtex at 0x7fbe2b651e50>,
#             <Reaction MG2tex at 0x7fbe2b6bd520>,
#             <Reaction MINCYCtex at 0x7fbe2b6ebeb0>,
#             <Reaction MMETtex at 0x7fbe2b694d90>,
#             <Reaction MNLtex at 0x7fbe2b694b50>,
#             <Reaction MNtex at 0x7fbe2b666fa0>,
#             <Reaction MOBDtex at 0x7fbe2b67ec40>,
#             <Reaction MSO3tex at 0x7fbe2b6264c0>,
#             <Reaction N2Otex at 0x7fbe2b5cdf10>,
#             <Reaction NACtex at 0x7fbe2b612f10>,
#             <Reaction NAtex at 0x7fbe2b5f6f40>,
#             <Reaction NH4tex at 0x7fbe2b587fd0>,
#             <Reaction NI2tex at 0x7fbe2b5b0fa0>,
#             <Reaction NMNtex at 0x7fbe2b5b08e0>,
#             <Reaction NO2tex at 0x7fbe2b572f10>,
#             <Reaction NO3tex at 0x7fbe2b587d90>,
#             <Reaction NOtex at 0x7fbe2b587cd0>,
#             <Reaction O2Stex at 0x7fbe2b489df0>,
#             <Reaction O2tex at 0x7fbe2b489970>,
#             <Reaction OCTAtex at 0x7fbe2b51beb0>,
#             <Reaction ORNtex at 0x7fbe2b4f3ee0>,
#             <Reaction OROTtex at 0x7fbe2b489c10>,
#             <Reaction PACALDtex at 0x7fbe2b4b2d00>,
#             <Reaction PACt1 at 0x7fbe2b036b20>,
#             <Reaction PEAMNtex at 0x7fbe2b49daf0>,
#             <Reaction PENGt1 at 0x7fbe2b036f10>,
#             <Reaction PHEtex at 0x7fbe2b391670>,
#             <Reaction PItex at 0x7fbe2b3ab970>,
#             <Reaction PNTOtex at 0x7fbe2b076880>,
#             <Reaction PPALtex at 0x7fbe2b021f40>,
#             <Reaction PPAtex at 0x7fbe2b021fd0>,
#             <Reaction PPPNtex at 0x7fbe2aff4f40>,
#             <Reaction PPTtex at 0x7fbe2af9b9a0>,
#             <Reaction PROGLYtex at 0x7fbe2b391ac0>,
#             <Reaction PROtex at 0x7fbe2b3abf40>,
#             <Reaction PSCLYStex at 0x7fbe2b3abc70>,
#             <Reaction PSERtex at 0x7fbe2b354f70>,
#             <Reaction PTRCtex at 0x7fbe2b32bd90>,
#             <Reaction PYDAMtex at 0x7fbe2b2d3940>,
#             <Reaction PYDXNtex at 0x7fbe2b2d3e80>,
#             <Reaction PYDXtex at 0x7fbe2b2d3a90>,
#             <Reaction PYRtex at 0x7fbe2b340fd0>,
#             <Reaction QUIN2tex at 0x7fbe2b36ab20>,
#             <Reaction R5Ptex at 0x7fbe2b37ffa0>,
#             <Reaction RAFFtex at 0x7fbe2b00bf40>,
#             <Reaction RIBtex at 0x7fbe2b32beb0>,
#             <Reaction RMNtex at 0x7fbe2b315760>,
#             <Reaction SALCNtex at 0x7fbe2b0768e0>,
#             <Reaction SBTtex at 0x7fbe2b2b6c40>,
#             <Reaction SELtex at 0x7fbe2b25ec10>,
#             <Reaction SERtex at 0x7fbe2b230e80>,
#             <Reaction SKMtex at 0x7fbe2b1d9fd0>,
#             <Reaction SLNTtex at 0x7fbe2b1d9e20>,
#             <Reaction SO2tex at 0x7fbe2b1edf40>,
#             <Reaction SO3tex at 0x7fbe2b1edeb0>,
#             <Reaction SO4tex at 0x7fbe2b1d9dc0>,
#             <Reaction SPMDtex at 0x7fbe2b2e7e20>,
#             <Reaction SUCCtex at 0x7fbe2b249ee0>,
#             <Reaction SUCRtex at 0x7fbe2b273a60>,
#             <Reaction SULFACtex at 0x7fbe2b207850>,
#             <Reaction TARTRDtex at 0x7fbe2b21cb80>,
#             <Reaction TARTRtex at 0x7fbe2b21cfd0>,
#             <Reaction TAURtex at 0x7fbe2b230d30>,
#             <Reaction TCYNTtex at 0x7fbe2b1c3d90>,
#             <Reaction THMDtex at 0x7fbe2b183d60>,
#             <Reaction THMtex at 0x7fbe2b183670>,
#             <Reaction THRPtex at 0x7fbe2b194e20>,
#             <Reaction THRtex at 0x7fbe2b1aa9a0>,
#             <Reaction THYMtex at 0x7fbe2b1aabe0>,
#             <Reaction TMAOtex at 0x7fbe2b1bea90>,
#             <Reaction TMAtex at 0x7fbe2b1bec70>,
#             <Reaction TREtex at 0x7fbe2b10edf0>,
#             <Reaction TRPtex at 0x7fbe2b138af0>,
#             <Reaction TSULtex at 0x7fbe2b138be0>,
#             <Reaction TTRCYCtex at 0x7fbe2b0cfac0>,
#             <Reaction TUNGStex at 0x7fbe2b0e3f70>,
#             <Reaction TYMtex at 0x7fbe2b0e3bb0>,
#             <Reaction TYRPtex at 0x7fbe2b0f7fa0>,
#             <Reaction TYRtex at 0x7fbe2b183c10>,
#             <Reaction UACGAMtex at 0x7fbe2b1be1f0>,
#             <Reaction UDPACGALtex at 0x7fbe2b167d00>,
#             <Reaction UDPGALtex at 0x7fbe2b17af10>,
#             <Reaction UDPGLCURtex at 0x7fbe2b10efa0>,
#             <Reaction UDPGtex at 0x7fbe2b167f10>,
#             <Reaction UMPtex at 0x7fbe2b0cfdf0>,
#             <Reaction URAtex at 0x7fbe2b0e3be0>,
#             <Reaction UREAtex at 0x7fbe2b0f7f10>,
#             <Reaction VALtex at 0x7fbe2b0e3760>,
#             <Reaction XANtex at 0x7fbe2b08b970>,
#             <Reaction XMPtex at 0x7fbe2b0a3f40>,
#             <Reaction XTSNtex at 0x7fbe2b0b73d0>,
#             <Reaction XYLUtex at 0x7fbe2b04cee0>,
#             <Reaction XYLtex at 0x7fbe2b060ac0>,
#             <Reaction Zn2tex at 0x7fbe2b076670>})}

# %%
i= -1

J=list()
C=list()
J.append(a.genes[0].name)
C.append(a.genes[0].reactions)

dictionary = dict(zip(J, C))

while i <1344:
   
    J= list()
    C= list()
    
    J.append(a.genes[i].name)
    C.append(a.genes[i].reactions)

    dictionary2 = dict(zip(J, C))
    dictionary.update(dictionary2)
    
    i=i+1

dictionary
# Out:
# {'PhoE': frozenset({<Reaction 12PPDRtex at 0x7fbe2bf9bc10>,
#             <Reaction 12PPDStex at 0x7fbe2bf9bca0>,
#             <Reaction 23CAMPtex at 0x7fbe2bf9bfd0>,
#             <Reaction 23CCMPtex at 0x7fbe2bf9bdc0>,
#             <Reaction 23CGMPtex at 0x7fbe2bfaa460>,
#             <Reaction 23CUMPtex at 0x7fbe2bf9b910>,
#             <Reaction 23DAPPAtex at 0x7fbe2bf9b970>,
#             <Reaction 26DAHtex at 0x7fbe2bfb88e0>,
#             <Reaction 34dhpactex at 0x7fbe2bf73ee0>,
#             <Reaction 3AMPtex at 0x7fbe2bf73f70>,
#             <Reaction 3CMPtex at 0x7fbe2bf73b50>,
#             <Reaction 3GMPtex at 0x7fbe2bf73f10>,
#             <Reaction 3HPPtex at 0x7fbe2bf0fd60>,
#             <Reaction 3PEPTtex at 0x7fbe2bee1b50>,
#             <Reaction 3UMPtex at 0x7fbe2bee1dc0>,
#             <Reaction 3hoxpactex at 0x7fbe2b021c10>,
#             <Reaction 4HOXPACDtex at 0x7fbe2bef08e0>,
#             <Reaction 4PEPTtex at 0x7fbe2befef70>,
#             <Reaction 4hoxpactex at 0x7fbe2b021cd0>,
#             <Reaction 5DGLCNtex at 0x7fbe2be8c520>,
#             <Reaction 5MTRtex at 0x7fbe2be8cf70>,
#             <Reaction 6APAt1 at 0x7fbe2b036820>,
#             <Reaction ABUTtex at 0x7fbe2bf1bf40>,
#             <Reaction ACACtex at 0x7fbe2bf37fa0>,
#             <Reaction ACALDtex at 0x7fbe2bec7b50>,
#             <Reaction ACGAL1Ptex at 0x7fbe2bec7f70>,
#             <Reaction ACGALtex at 0x7fbe2bee1a60>,
#             <Reaction ACGAM1Ptex at 0x7fbe2bee1fd0>,
#             <Reaction ACGAtex at 0x7fbe2bef0eb0>,
#             <Reaction ACMANAtex at 0x7fbe2befef10>,
#             <Reaction ACMUMtex at 0x7fbe2be8ce80>,
#             <Reaction ACSERtex at 0x7fbe2beb6d60>,
#             <Reaction ACtex at 0x7fbe2be56c40>,
#             <Reaction ADEtex at 0x7fbe2be64e80>,
#             <Reaction AGMtex at 0x7fbe2bdd4e80>,
#             <Reaction AKGtex at 0x7fbe2be47f10>,
#             <Reaction ALAALAtex at 0x7fbe2beb6730>,
#             <Reaction ALAtex at 0x7fbe2be74f10>,
#             <Reaction ALLTNtex at 0x7fbe2be23670>,
#             <Reaction ALLtex at 0x7fbe2be34c10>,
#             <Reaction AMPtex at 0x7fbe2bde3ee0>,
#             <Reaction ANHGMtex at 0x7fbe2bde3970>,
#             <Reaction ARBTtex at 0x7fbe2bc5ba90>,
#             <Reaction ARBtex at 0x7fbe2bc1ef10>,
#             <Reaction ARGtex at 0x7fbe2bb63eb0>,
#             <Reaction ASCBtex at 0x7fbe2bb1bb80>,
#             <Reaction ASNtex at 0x7fbe2ba5cdc0>,
#             <Reaction ASO3tex at 0x7fbe2ba03670>,
#             <Reaction ASPtex at 0x7fbe2bde3c70>,
#             <Reaction BALAtex at 0x7fbe2bd93fa0>,
#             <Reaction BTNtex at 0x7fbe2bda3f40>,
#             <Reaction BUTSO3tex at 0x7fbe2bdb2580>,
#             <Reaction BUTtex at 0x7fbe2bd52f70>,
#             <Reaction CA2tex at 0x7fbe2bd5ecd0>,
#             <Reaction CD2tex at 0x7fbe2bd10910>,
#             <Reaction CGLYtex at 0x7fbe2bda3fa0>,
#             <Reaction CHLtex at 0x7fbe2bda3f10>,
#             <Reaction CHTBStex at 0x7fbe2bdbeca0>,
#             <Reaction CITtex at 0x7fbe2bdbee20>,
#             <Reaction CLBtex at 0x7fbe2b060ee0>,
#             <Reaction CLtex at 0x7fbe2bd7efd0>,
#             <Reaction CMPtex at 0x7fbe2bd7ef70>,
#             <Reaction CMtex at 0x7fbe2bd6caf0>,
#             <Reaction CO2tex at 0x7fbe2bd10f40>,
#             <Reaction COBALT2tex at 0x7fbe2bd1fd30>,
#             <Reaction CRNDtex at 0x7fbe2bcd0d00>,
#             <Reaction CRNtex at 0x7fbe2bcdeb20>,
#             <Reaction CSNtex at 0x7fbe2bcefdf0>,
#             <Reaction CU2tex at 0x7fbe2bc8de80>,
#             <Reaction CUtex at 0x7fbe2bc9eaf0>,
#             <Reaction CYANtex at 0x7fbe2bc9ed60>,
#             <Reaction CYNTtex at 0x7fbe2bcadc70>,
#             <Reaction CYSDtex at 0x7fbe2bcaddc0>,
#             <Reaction CYStex at 0x7fbe2bc4cdc0>,
#             <Reaction CYTDtex at 0x7fbe2bc5be50>,
#             <Reaction DALAtex at 0x7fbe2bcd0c40>,
#             <Reaction DAMPtex at 0x7fbe2bcefe20>,
#             <Reaction DAPtex at 0x7fbe2bcfefd0>,
#             <Reaction DARBtex at 0x7fbe2af6bdc0>,
#             <Reaction DCAtex at 0x7fbe2bc9ebb0>,
#             <Reaction DCMPtex at 0x7fbe2bc9ea90>,
#             <Reaction DDGLCNtex at 0x7fbe2bcad8e0>,
#             <Reaction DGMPtex at 0x7fbe2bcbcd60>,
#             <Reaction DGSNtex at 0x7fbe2bc4cc70>,
#             <Reaction DHAtex at 0x7fbe2bc5bca0>,
#             <Reaction DIMPtex at 0x7fbe2bc0af40>,
#             <Reaction DINStex at 0x7fbe2bc6ca60>,
#             <Reaction DMSOtex at 0x7fbe2bc33e80>,
#             <Reaction DMStex at 0x7fbe2bc33a30>,
#             <Reaction DOPAtex at 0x7fbe2bbc6eb0>,
#             <Reaction DOXRBCNtex at 0x7fbe2bbc6f10>,
#             <Reaction DSERtex at 0x7fbe2bbea7c0>,
#             <Reaction DTMPtex at 0x7fbe2bbfed90>,
#             <Reaction DUMPtex at 0x7fbe2bbfeaf0>,
#             <Reaction D_LACtex at 0x7fbe2bc7bdc0>,
#             <Reaction ETHAtex at 0x7fbe2bb92ee0>,
#             <Reaction ETHSO3tex at 0x7fbe2bb50dc0>,
#             <Reaction ETOHtex at 0x7fbe2bbfefd0>,
#             <Reaction F6Ptex at 0x7fbe2bb63c10>,
#             <Reaction FALDtex at 0x7fbe2bb1bf10>,
#             <Reaction FE2tex at 0x7fbe2bae8fa0>,
#             <Reaction FE3tex at 0x7fbe2bab5d00>,
#             <Reaction FORtex at 0x7fbe2baa3d90>,
#             <Reaction FRULYStex at 0x7fbe2ba49a60>,
#             <Reaction FRUURtex at 0x7fbe2ba49d90>,
#             <Reaction FRUtex at 0x7fbe2ba5cdf0>,
#             <Reaction FUCtex at 0x7fbe2ba5c8e0>,
#             <Reaction FUMtex at 0x7fbe2ba6de80>,
#             <Reaction FUSAtex at 0x7fbe2ba6dfa0>,
#             <Reaction G1Ptex at 0x7fbe2ba16eb0>,
#             <Reaction G3PCtex at 0x7fbe2ba16ee0>,
#             <Reaction G3PEtex at 0x7fbe2ba28d90>,
#             <Reaction G3PGtex at 0x7fbe31783a60>,
#             <Reaction G3PItex at 0x7fbe3179c5b0>,
#             <Reaction G3PStex at 0x7fbe3179c280>,
#             <Reaction G6Ptex at 0x7fbe31753e50>,
#             <Reaction GAL1Ptex at 0x7fbe3176ba90>,
#             <Reaction GALAMtex at 0x7fbe2b00b5e0>,
#             <Reaction GALBDtex at 0x7fbe31735eb0>,
#             <Reaction GALCTNLtex at 0x7fbe31778130>,
#             <Reaction GALCTNtex at 0x7fbe31699850>,
#             <Reaction GALCTtex at 0x7fbe31692c70>,
#             <Reaction GALTtex at 0x7fbe31699c40>,
#             <Reaction GALURtex at 0x7fbe316e7f70>,
#             <Reaction GALtex at 0x7fbe308bb250>,
#             <Reaction GAMAN6Ptex at 0x7fbe308c4fd0>,
#             <Reaction GAMtex at 0x7fbe30931160>,
#             <Reaction GBBTNtex at 0x7fbe30881b50>,
#             <Reaction GDPtex at 0x7fbe30839e80>,
#             <Reaction GLCNtex at 0x7fbe3172e5e0>,
#             <Reaction GLCRtex at 0x7fbe316cf370>,
#             <Reaction GLCUR1Ptex at 0x7fbe316eeee0>,
#             <Reaction GLCURtex at 0x7fbe316a2550>,
#             <Reaction GLCtex_copy1 at 0x7fbe31760790>,
#             <Reaction GLNtex at 0x7fbe308cfeb0>,
#             <Reaction GLUtex at 0x7fbe308afcd0>,
#             <Reaction GLYALDtex at 0x7fbe30857f10>,
#             <Reaction GLYBtex at 0x7fbe30367820>,
#             <Reaction GLYC2Ptex at 0x7fbe3088ca00>,
#             <Reaction GLYC3Ptex at 0x7fbe3315c160>,
#             <Reaction GLYCAtex at 0x7fbe308c4d60>,
#             <Reaction GLYCLTtex at 0x7fbe2b8ce610>,
#             <Reaction GLYCtex at 0x7fbe2b846eb0>,
#             <Reaction GLYtex at 0x7fbe2b7eabb0>,
#             <Reaction GMPtex at 0x7fbe2b71bbb0>,
#             <Reaction GSNtex at 0x7fbe2b5decd0>,
#             <Reaction GTHOXtex at 0x7fbe2b59eeb0>,
#             <Reaction GTHRDtex at 0x7fbe2b508f10>,
#             <Reaction GTPtex at 0x7fbe2b49dd60>,
#             <Reaction H2O2tex at 0x7fbe2ba3b4f0>,
#             <Reaction H2Otex at 0x7fbe2b9235e0>,
#             <Reaction H2Stex at 0x7fbe2b937ee0>,
#             <Reaction H2tex at 0x7fbe2b937370>,
#             <Reaction HCINNMtex at 0x7fbe2b8f6e20>,
#             <Reaction HG2tex at 0x7fbe2b8a9eb0>,
#             <Reaction HIStex at 0x7fbe2b846880>,
#             <Reaction HOMtex at 0x7fbe2b878f40>,
#             <Reaction HPPPNtex at 0x7fbe2b86fd60>,
#             <Reaction HXAtex at 0x7fbe3086d940>,
#             <Reaction HYXNtex at 0x7fbe2b8ceee0>,
#             <Reaction Htex at 0x7fbe2b937f40>,
#             <Reaction IDONtex at 0x7fbe2b8a09d0>,
#             <Reaction ILEtex at 0x7fbe2b8b2820>,
#             <Reaction IMPtex at 0x7fbe2b8bb850>,
#             <Reaction INDOLEtex at 0x7fbe2b864640>,
#             <Reaction INSTtex at 0x7fbe2b84ed00>,
#             <Reaction ISETACtex at 0x7fbe2b81daf0>,
#             <Reaction Ktex at 0x7fbe2b7c3eb0>,
#             <Reaction LALADGLUtex at 0x7fbe2b7eaf10>,
#             <Reaction LALALGLUtex at 0x7fbe2b7ea880>,
#             <Reaction LCTStex at 0x7fbe2b7feee0>,
#             <Reaction LEUtex at 0x7fbe2b7a5e50>,
#             <Reaction LIPOtex at 0x7fbe2b74bf40>,
#             <Reaction LYStex at 0x7fbe2b7749a0>,
#             <Reaction LYXtex at 0x7fbe2b707b80>,
#             <Reaction L_LACtex_copy1 at 0x7fbe2b7d6ee0>,
#             <Reaction L_LACtex_copy2 at 0x7fbe2b0b7cd0>,
#             <Reaction MALDtex at 0x7fbe2b707f40>,
#             <Reaction MALtex at 0x7fbe2b6c4fd0>,
#             <Reaction MAN6Ptex at 0x7fbe2b6d8a60>,
#             <Reaction MANGLYCtex at 0x7fbe2b71bd00>,
#             <Reaction MANtex at 0x7fbe2b730f70>,
#             <Reaction MELIBtex at 0x7fbe2b6ebfd0>,
#             <Reaction MEOHtex at 0x7fbe2b6fdd60>,
#             <Reaction METDtex at 0x7fbe2b6a9b50>,
#             <Reaction METSOX1tex at 0x7fbe2b6a9be0>,
#             <Reaction METSOX2tex at 0x7fbe2b6a9d90>,
#             <Reaction METtex at 0x7fbe2b651e50>,
#             <Reaction MG2tex at 0x7fbe2b6bd520>,
#             <Reaction MINCYCtex at 0x7fbe2b6ebeb0>,
#             <Reaction MMETtex at 0x7fbe2b694d90>,
#             <Reaction MNLtex at 0x7fbe2b694b50>,
#             <Reaction MNtex at 0x7fbe2b666fa0>,
#             <Reaction MOBDtex at 0x7fbe2b67ec40>,
#             <Reaction MSO3tex at 0x7fbe2b6264c0>,
#             <Reaction N2Otex at 0x7fbe2b5cdf10>,
#             <Reaction NACtex at 0x7fbe2b612f10>,
#             <Reaction NAtex at 0x7fbe2b5f6f40>,
#             <Reaction NH4tex at 0x7fbe2b587fd0>,
#             <Reaction NI2tex at 0x7fbe2b5b0fa0>,
#             <Reaction NMNtex at 0x7fbe2b5b08e0>,
#             <Reaction NO2tex at 0x7fbe2b572f10>,
#             <Reaction NO3tex at 0x7fbe2b587d90>,
#             <Reaction NOtex at 0x7fbe2b587cd0>,
#             <Reaction O2Stex at 0x7fbe2b489df0>,
#             <Reaction O2tex at 0x7fbe2b489970>,
#             <Reaction OCTAtex at 0x7fbe2b51beb0>,
#             <Reaction ORNtex at 0x7fbe2b4f3ee0>,
#             <Reaction OROTtex at 0x7fbe2b489c10>,
#             <Reaction PACALDtex at 0x7fbe2b4b2d00>,
#             <Reaction PACt1 at 0x7fbe2b036b20>,
#             <Reaction PEAMNtex at 0x7fbe2b49daf0>,
#             <Reaction PENGt1 at 0x7fbe2b036f10>,
#             <Reaction PHEtex at 0x7fbe2b391670>,
#             <Reaction PItex at 0x7fbe2b3ab970>,
#             <Reaction PNTOtex at 0x7fbe2b076880>,
#             <Reaction PPALtex at 0x7fbe2b021f40>,
#             <Reaction PPAtex at 0x7fbe2b021fd0>,
#             <Reaction PPPNtex at 0x7fbe2aff4f40>,
#             <Reaction PPTtex at 0x7fbe2af9b9a0>,
#             <Reaction PROGLYtex at 0x7fbe2b391ac0>,
#             <Reaction PROtex at 0x7fbe2b3abf40>,
#             <Reaction PSCLYStex at 0x7fbe2b3abc70>,
#             <Reaction PSERtex at 0x7fbe2b354f70>,
#             <Reaction PTRCtex at 0x7fbe2b32bd90>,
#             <Reaction PYDAMtex at 0x7fbe2b2d3940>,
#             <Reaction PYDXNtex at 0x7fbe2b2d3e80>,
#             <Reaction PYDXtex at 0x7fbe2b2d3a90>,
#             <Reaction PYRtex at 0x7fbe2b340fd0>,
#             <Reaction QUIN2tex at 0x7fbe2b36ab20>,
#             <Reaction R5Ptex at 0x7fbe2b37ffa0>,
#             <Reaction RAFFtex at 0x7fbe2b00bf40>,
#             <Reaction RIBtex at 0x7fbe2b32beb0>,
#             <Reaction RMNtex at 0x7fbe2b315760>,
#             <Reaction SALCNtex at 0x7fbe2b0768e0>,
#             <Reaction SBTtex at 0x7fbe2b2b6c40>,
#             <Reaction SELtex at 0x7fbe2b25ec10>,
#             <Reaction SERtex at 0x7fbe2b230e80>,
#             <Reaction SKMtex at 0x7fbe2b1d9fd0>,
#             <Reaction SLNTtex at 0x7fbe2b1d9e20>,
#             <Reaction SO2tex at 0x7fbe2b1edf40>,
#             <Reaction SO3tex at 0x7fbe2b1edeb0>,
#             <Reaction SO4tex at 0x7fbe2b1d9dc0>,
#             <Reaction SPMDtex at 0x7fbe2b2e7e20>,
#             <Reaction SUCCtex at 0x7fbe2b249ee0>,
#             <Reaction SUCRtex at 0x7fbe2b273a60>,
#             <Reaction SULFACtex at 0x7fbe2b207850>,
#             <Reaction TARTRDtex at 0x7fbe2b21cb80>,
#             <Reaction TARTRtex at 0x7fbe2b21cfd0>,
#             <Reaction TAURtex at 0x7fbe2b230d30>,
#             <Reaction TCYNTtex at 0x7fbe2b1c3d90>,
#             <Reaction THMDtex at 0x7fbe2b183d60>,
#             <Reaction THMtex at 0x7fbe2b183670>,
#             <Reaction THRPtex at 0x7fbe2b194e20>,
#             <Reaction THRtex at 0x7fbe2b1aa9a0>,
#             <Reaction THYMtex at 0x7fbe2b1aabe0>,
#             <Reaction TMAOtex at 0x7fbe2b1bea90>,
#             <Reaction TMAtex at 0x7fbe2b1bec70>,
#             <Reaction TREtex at 0x7fbe2b10edf0>,
#             <Reaction TRPtex at 0x7fbe2b138af0>,
#             <Reaction TSULtex at 0x7fbe2b138be0>,
#             <Reaction TTRCYCtex at 0x7fbe2b0cfac0>,
#             <Reaction TUNGStex at 0x7fbe2b0e3f70>,
#             <Reaction TYMtex at 0x7fbe2b0e3bb0>,
#             <Reaction TYRPtex at 0x7fbe2b0f7fa0>,
#             <Reaction TYRtex at 0x7fbe2b183c10>,
#             <Reaction UACGAMtex at 0x7fbe2b1be1f0>,
#             <Reaction UDPACGALtex at 0x7fbe2b167d00>,
#             <Reaction UDPGALtex at 0x7fbe2b17af10>,
#             <Reaction UDPGLCURtex at 0x7fbe2b10efa0>,
#             <Reaction UDPGtex at 0x7fbe2b167f10>,
#             <Reaction UMPtex at 0x7fbe2b0cfdf0>,
#             <Reaction URAtex at 0x7fbe2b0e3be0>,
#             <Reaction UREAtex at 0x7fbe2b0f7f10>,
#             <Reaction VALtex at 0x7fbe2b0e3760>,
#             <Reaction XANtex at 0x7fbe2b08b970>,
#             <Reaction XMPtex at 0x7fbe2b0a3f40>,
#             <Reaction XTSNtex at 0x7fbe2b0b73d0>,
#             <Reaction XYLUtex at 0x7fbe2b04cee0>,
#             <Reaction XYLtex at 0x7fbe2b060ac0>,
#             <Reaction Zn2tex at 0x7fbe2b076670>}),
#  'YlbA': frozenset({<Reaction UGCIAMH at 0x7fbe2aee5f40>}),
#  'OmpC': frozenset({<Reaction 12PPDRtex at 0x7fbe2bf9bc10>,
#             <Reaction 12PPDStex at 0x7fbe2bf9bca0>,
#             <Reaction 23CAMPtex at 0x7fbe2bf9bfd0>,
#             <Reaction 23CCMPtex at 0x7fbe2bf9bdc0>,
#             <Reaction 23CGMPtex at 0x7fbe2bfaa460>,
#             <Reaction 23CUMPtex at 0x7fbe2bf9b910>,
#             <Reaction 23DAPPAtex at 0x7fbe2bf9b970>,
#             <Reaction 26DAHtex at 0x7fbe2bfb88e0>,
#             <Reaction 34dhpactex at 0x7fbe2bf73ee0>,
#             <Reaction 3AMPtex at 0x7fbe2bf73f70>,
#             <Reaction 3CMPtex at 0x7fbe2bf73b50>,
#             <Reaction 3GMPtex at 0x7fbe2bf73f10>,
#             <Reaction 3HPPtex at 0x7fbe2bf0fd60>,
#             <Reaction 3PEPTtex at 0x7fbe2bee1b50>,
#             <Reaction 3UMPtex at 0x7fbe2bee1dc0>,
#             <Reaction 3hoxpactex at 0x7fbe2b021c10>,
#             <Reaction 4HOXPACDtex at 0x7fbe2bef08e0>,
#             <Reaction 4PEPTtex at 0x7fbe2befef70>,
#             <Reaction 4hoxpactex at 0x7fbe2b021cd0>,
#             <Reaction 5DGLCNtex at 0x7fbe2be8c520>,
#             <Reaction 5MTRtex at 0x7fbe2be8cf70>,
#             <Reaction 6APAt1 at 0x7fbe2b036820>,
#             <Reaction ABUTtex at 0x7fbe2bf1bf40>,
#             <Reaction ACACtex at 0x7fbe2bf37fa0>,
#             <Reaction ACALDtex at 0x7fbe2bec7b50>,
#             <Reaction ACGAL1Ptex at 0x7fbe2bec7f70>,
#             <Reaction ACGALtex at 0x7fbe2bee1a60>,
#             <Reaction ACGAM1Ptex at 0x7fbe2bee1fd0>,
#             <Reaction ACGAtex at 0x7fbe2bef0eb0>,
#             <Reaction ACMANAtex at 0x7fbe2befef10>,
#             <Reaction ACMUMtex at 0x7fbe2be8ce80>,
#             <Reaction ACNAMtex at 0x7fbe2befeca0>,
#             <Reaction ACSERtex at 0x7fbe2beb6d60>,
#             <Reaction ACtex at 0x7fbe2be56c40>,
#             <Reaction ADEtex at 0x7fbe2be64e80>,
#             <Reaction AGMtex at 0x7fbe2bdd4e80>,
#             <Reaction AKGtex at 0x7fbe2be47f10>,
#             <Reaction ALAALAtex at 0x7fbe2beb6730>,
#             <Reaction ALAtex at 0x7fbe2be74f10>,
#             <Reaction ALLTNtex at 0x7fbe2be23670>,
#             <Reaction ALLtex at 0x7fbe2be34c10>,
#             <Reaction AMPtex at 0x7fbe2bde3ee0>,
#             <Reaction ANHGMtex at 0x7fbe2bde3970>,
#             <Reaction ARBTtex at 0x7fbe2bc5ba90>,
#             <Reaction ARBtex at 0x7fbe2bc1ef10>,
#             <Reaction ARGtex at 0x7fbe2bb63eb0>,
#             <Reaction ASCBtex at 0x7fbe2bb1bb80>,
#             <Reaction ASNtex at 0x7fbe2ba5cdc0>,
#             <Reaction ASO3tex at 0x7fbe2ba03670>,
#             <Reaction ASPtex at 0x7fbe2bde3c70>,
#             <Reaction BALAtex at 0x7fbe2bd93fa0>,
#             <Reaction BTNtex at 0x7fbe2bda3f40>,
#             <Reaction BUTSO3tex at 0x7fbe2bdb2580>,
#             <Reaction BUTtex at 0x7fbe2bd52f70>,
#             <Reaction CA2tex at 0x7fbe2bd5ecd0>,
#             <Reaction CD2tex at 0x7fbe2bd10910>,
#             <Reaction CGLYtex at 0x7fbe2bda3fa0>,
#             <Reaction CHLtex at 0x7fbe2bda3f10>,
#             <Reaction CHTBStex at 0x7fbe2bdbeca0>,
#             <Reaction CITtex at 0x7fbe2bdbee20>,
#             <Reaction CLBtex at 0x7fbe2b060ee0>,
#             <Reaction CLtex at 0x7fbe2bd7efd0>,
#             <Reaction CMPtex at 0x7fbe2bd7ef70>,
#             <Reaction CMtex at 0x7fbe2bd6caf0>,
#             <Reaction CO2tex at 0x7fbe2bd10f40>,
#             <Reaction COBALT2tex at 0x7fbe2bd1fd30>,
#             <Reaction CRNDtex at 0x7fbe2bcd0d00>,
#             <Reaction CRNtex at 0x7fbe2bcdeb20>,
#             <Reaction CSNtex at 0x7fbe2bcefdf0>,
#             <Reaction CU2tex at 0x7fbe2bc8de80>,
#             <Reaction CUtex at 0x7fbe2bc9eaf0>,
#             <Reaction CYANtex at 0x7fbe2bc9ed60>,
#             <Reaction CYNTtex at 0x7fbe2bcadc70>,
#             <Reaction CYSDtex at 0x7fbe2bcaddc0>,
#             <Reaction CYStex at 0x7fbe2bc4cdc0>,
#             <Reaction CYTDtex at 0x7fbe2bc5be50>,
#             <Reaction DALAtex at 0x7fbe2bcd0c40>,
#             <Reaction DAMPtex at 0x7fbe2bcefe20>,
#             <Reaction DAPtex at 0x7fbe2bcfefd0>,
#             <Reaction DARBtex at 0x7fbe2af6bdc0>,
#             <Reaction DCAtex at 0x7fbe2bc9ebb0>,
#             <Reaction DCMPtex at 0x7fbe2bc9ea90>,
#             <Reaction DDGLCNtex at 0x7fbe2bcad8e0>,
#             <Reaction DGMPtex at 0x7fbe2bcbcd60>,
#             <Reaction DGSNtex at 0x7fbe2bc4cc70>,
#             <Reaction DHAtex at 0x7fbe2bc5bca0>,
#             <Reaction DIMPtex at 0x7fbe2bc0af40>,
#             <Reaction DINStex at 0x7fbe2bc6ca60>,
#             <Reaction DMSOtex at 0x7fbe2bc33e80>,
#             <Reaction DMStex at 0x7fbe2bc33a30>,
#             <Reaction DOPAtex at 0x7fbe2bbc6eb0>,
#             <Reaction DOXRBCNtex at 0x7fbe2bbc6f10>,
#             <Reaction DSERtex at 0x7fbe2bbea7c0>,
#             <Reaction DTMPtex at 0x7fbe2bbfed90>,
#             <Reaction DUMPtex at 0x7fbe2bbfeaf0>,
#             <Reaction D_LACtex at 0x7fbe2bc7bdc0>,
#             <Reaction ETHAtex at 0x7fbe2bb92ee0>,
#             <Reaction ETHSO3tex at 0x7fbe2bb50dc0>,
#             <Reaction ETOHtex at 0x7fbe2bbfefd0>,
#             <Reaction F6Ptex at 0x7fbe2bb63c10>,
#             <Reaction FALDtex at 0x7fbe2bb1bf10>,
#             <Reaction FE2tex at 0x7fbe2bae8fa0>,
#             <Reaction FE3tex at 0x7fbe2bab5d00>,
#             <Reaction FORtex at 0x7fbe2baa3d90>,
#             <Reaction FRULYStex at 0x7fbe2ba49a60>,
#             <Reaction FRUURtex at 0x7fbe2ba49d90>,
#             <Reaction FRUtex at 0x7fbe2ba5cdf0>,
#             <Reaction FUCtex at 0x7fbe2ba5c8e0>,
#             <Reaction FUMtex at 0x7fbe2ba6de80>,
#             <Reaction FUSAtex at 0x7fbe2ba6dfa0>,
#             <Reaction G1Ptex at 0x7fbe2ba16eb0>,
#             <Reaction G3PCtex at 0x7fbe2ba16ee0>,
#             <Reaction G3PEtex at 0x7fbe2ba28d90>,
#             <Reaction G3PGtex at 0x7fbe31783a60>,
#             <Reaction G3PItex at 0x7fbe3179c5b0>,
#             <Reaction G3PStex at 0x7fbe3179c280>,
#             <Reaction G6Ptex at 0x7fbe31753e50>,
#             <Reaction GAL1Ptex at 0x7fbe3176ba90>,
#             <Reaction GALAMtex at 0x7fbe2b00b5e0>,
#             <Reaction GALBDtex at 0x7fbe31735eb0>,
#             <Reaction GALCTNLtex at 0x7fbe31778130>,
#             <Reaction GALCTNtex at 0x7fbe31699850>,
#             <Reaction GALCTtex at 0x7fbe31692c70>,
#             <Reaction GALTtex at 0x7fbe31699c40>,
#             <Reaction GALURtex at 0x7fbe316e7f70>,
#             <Reaction GALtex at 0x7fbe308bb250>,
#             <Reaction GAMAN6Ptex at 0x7fbe308c4fd0>,
#             <Reaction GAMtex at 0x7fbe30931160>,
#             <Reaction GBBTNtex at 0x7fbe30881b50>,
#             <Reaction GDPtex at 0x7fbe30839e80>,
#             <Reaction GLCNtex at 0x7fbe3172e5e0>,
#             <Reaction GLCRtex at 0x7fbe316cf370>,
#             <Reaction GLCUR1Ptex at 0x7fbe316eeee0>,
#             <Reaction GLCURtex at 0x7fbe316a2550>,
#             <Reaction GLCtex_copy1 at 0x7fbe31760790>,
#             <Reaction GLNtex at 0x7fbe308cfeb0>,
#             <Reaction GLUtex at 0x7fbe308afcd0>,
#             <Reaction GLYALDtex at 0x7fbe30857f10>,
#             <Reaction GLYBtex at 0x7fbe30367820>,
#             <Reaction GLYC2Ptex at 0x7fbe3088ca00>,
#             <Reaction GLYC3Ptex at 0x7fbe3315c160>,
#             <Reaction GLYCAtex at 0x7fbe308c4d60>,
#             <Reaction GLYCLTtex at 0x7fbe2b8ce610>,
#             <Reaction GLYCtex at 0x7fbe2b846eb0>,
#             <Reaction GLYtex at 0x7fbe2b7eabb0>,
#             <Reaction GMPtex at 0x7fbe2b71bbb0>,
#             <Reaction GSNtex at 0x7fbe2b5decd0>,
#             <Reaction GTHOXtex at 0x7fbe2b59eeb0>,
#             <Reaction GTHRDtex at 0x7fbe2b508f10>,
#             <Reaction GTPtex at 0x7fbe2b49dd60>,
#             <Reaction H2O2tex at 0x7fbe2ba3b4f0>,
#             <Reaction H2Otex at 0x7fbe2b9235e0>,
#             <Reaction H2Stex at 0x7fbe2b937ee0>,
#             <Reaction H2tex at 0x7fbe2b937370>,
#             <Reaction HCINNMtex at 0x7fbe2b8f6e20>,
#             <Reaction HG2tex at 0x7fbe2b8a9eb0>,
#             <Reaction HIStex at 0x7fbe2b846880>,
#             <Reaction HOMtex at 0x7fbe2b878f40>,
#             <Reaction HPPPNtex at 0x7fbe2b86fd60>,
#             <Reaction HXAtex at 0x7fbe3086d940>,
#             <Reaction HYXNtex at 0x7fbe2b8ceee0>,
#             <Reaction Htex at 0x7fbe2b937f40>,
#             <Reaction IDONtex at 0x7fbe2b8a09d0>,
#             <Reaction ILEtex at 0x7fbe2b8b2820>,
#             <Reaction IMPtex at 0x7fbe2b8bb850>,
#             <Reaction INDOLEtex at 0x7fbe2b864640>,
#             <Reaction INSTtex at 0x7fbe2b84ed00>,
#             <Reaction ISETACtex at 0x7fbe2b81daf0>,
#             <Reaction Ktex at 0x7fbe2b7c3eb0>,
#             <Reaction LALADGLUtex at 0x7fbe2b7eaf10>,
#             <Reaction LALALGLUtex at 0x7fbe2b7ea880>,
#             <Reaction LCTStex at 0x7fbe2b7feee0>,
#             <Reaction LEUtex at 0x7fbe2b7a5e50>,
#             <Reaction LIPOtex at 0x7fbe2b74bf40>,
#             <Reaction LYStex at 0x7fbe2b7749a0>,
#             <Reaction LYXtex at 0x7fbe2b707b80>,
#             <Reaction L_LACtex_copy1 at 0x7fbe2b7d6ee0>,
#             <Reaction L_LACtex_copy2 at 0x7fbe2b0b7cd0>,
#             <Reaction MALDtex at 0x7fbe2b707f40>,
#             <Reaction MALtex at 0x7fbe2b6c4fd0>,
#             <Reaction MAN6Ptex at 0x7fbe2b6d8a60>,
#             <Reaction MANGLYCtex at 0x7fbe2b71bd00>,
#             <Reaction MANtex at 0x7fbe2b730f70>,
#             <Reaction MELIBtex at 0x7fbe2b6ebfd0>,
#             <Reaction MEOHtex at 0x7fbe2b6fdd60>,
#             <Reaction METDtex at 0x7fbe2b6a9b50>,
#             <Reaction METSOX1tex at 0x7fbe2b6a9be0>,
#             <Reaction METSOX2tex at 0x7fbe2b6a9d90>,
#             <Reaction METtex at 0x7fbe2b651e50>,
#             <Reaction MG2tex at 0x7fbe2b6bd520>,
#             <Reaction MINCYCtex at 0x7fbe2b6ebeb0>,
#             <Reaction MMETtex at 0x7fbe2b694d90>,
#             <Reaction MNLtex at 0x7fbe2b694b50>,
#             <Reaction MNtex at 0x7fbe2b666fa0>,
#             <Reaction MOBDtex at 0x7fbe2b67ec40>,
#             <Reaction MSO3tex at 0x7fbe2b6264c0>,
#             <Reaction N2Otex at 0x7fbe2b5cdf10>,
#             <Reaction NACtex at 0x7fbe2b612f10>,
#             <Reaction NAtex at 0x7fbe2b5f6f40>,
#             <Reaction NH4tex at 0x7fbe2b587fd0>,
#             <Reaction NI2tex at 0x7fbe2b5b0fa0>,
#             <Reaction NMNtex at 0x7fbe2b5b08e0>,
#             <Reaction NO2tex at 0x7fbe2b572f10>,
#             <Reaction NO3tex at 0x7fbe2b587d90>,
#             <Reaction NOtex at 0x7fbe2b587cd0>,
#             <Reaction O2Stex at 0x7fbe2b489df0>,
#             <Reaction O2tex at 0x7fbe2b489970>,
#             <Reaction OCTAtex at 0x7fbe2b51beb0>,
#             <Reaction ORNtex at 0x7fbe2b4f3ee0>,
#             <Reaction OROTtex at 0x7fbe2b489c10>,
#             <Reaction PACALDtex at 0x7fbe2b4b2d00>,
#             <Reaction PACt1 at 0x7fbe2b036b20>,
#             <Reaction PEAMNtex at 0x7fbe2b49daf0>,
#             <Reaction PENGt1 at 0x7fbe2b036f10>,
#             <Reaction PHEtex at 0x7fbe2b391670>,
#             <Reaction PItex at 0x7fbe2b3ab970>,
#             <Reaction PNTOtex at 0x7fbe2b076880>,
#             <Reaction PPALtex at 0x7fbe2b021f40>,
#             <Reaction PPAtex at 0x7fbe2b021fd0>,
#             <Reaction PPPNtex at 0x7fbe2aff4f40>,
#             <Reaction PPTtex at 0x7fbe2af9b9a0>,
#             <Reaction PROGLYtex at 0x7fbe2b391ac0>,
#             <Reaction PROtex at 0x7fbe2b3abf40>,
#             <Reaction PSCLYStex at 0x7fbe2b3abc70>,
#             <Reaction PSERtex at 0x7fbe2b354f70>,
#             <Reaction PTRCtex at 0x7fbe2b32bd90>,
#             <Reaction PYDAMtex at 0x7fbe2b2d3940>,
#             <Reaction PYDXNtex at 0x7fbe2b2d3e80>,
#             <Reaction PYDXtex at 0x7fbe2b2d3a90>,
#             <Reaction PYRtex at 0x7fbe2b340fd0>,
#             <Reaction QUIN2tex at 0x7fbe2b36ab20>,
#             <Reaction R5Ptex at 0x7fbe2b37ffa0>,
#             <Reaction RAFFtex at 0x7fbe2b00bf40>,
#             <Reaction RIBtex at 0x7fbe2b32beb0>,
#             <Reaction RMNtex at 0x7fbe2b315760>,
#             <Reaction SALCNtex at 0x7fbe2b0768e0>,
#             <Reaction SBTtex at 0x7fbe2b2b6c40>,
#             <Reaction SELtex at 0x7fbe2b25ec10>,
#             <Reaction SERtex at 0x7fbe2b230e80>,
#             <Reaction SKMtex at 0x7fbe2b1d9fd0>,
#             <Reaction SLNTtex at 0x7fbe2b1d9e20>,
#             <Reaction SO2tex at 0x7fbe2b1edf40>,
#             <Reaction SO3tex at 0x7fbe2b1edeb0>,
#             <Reaction SO4tex at 0x7fbe2b1d9dc0>,
#             <Reaction SPMDtex at 0x7fbe2b2e7e20>,
#             <Reaction SUCCtex at 0x7fbe2b249ee0>,
#             <Reaction SUCRtex at 0x7fbe2b273a60>,
#             <Reaction SULFACtex at 0x7fbe2b207850>,
#             <Reaction TARTRDtex at 0x7fbe2b21cb80>,
#             <Reaction TARTRtex at 0x7fbe2b21cfd0>,
#             <Reaction TAURtex at 0x7fbe2b230d30>,
#             <Reaction TCYNTtex at 0x7fbe2b1c3d90>,
#             <Reaction THMDtex at 0x7fbe2b183d60>,
#             <Reaction THMtex at 0x7fbe2b183670>,
#             <Reaction THRPtex at 0x7fbe2b194e20>,
#             <Reaction THRtex at 0x7fbe2b1aa9a0>,
#             <Reaction THYMtex at 0x7fbe2b1aabe0>,
#             <Reaction TMAOtex at 0x7fbe2b1bea90>,
#             <Reaction TMAtex at 0x7fbe2b1bec70>,
#             <Reaction TREtex at 0x7fbe2b10edf0>,
#             <Reaction TRPtex at 0x7fbe2b138af0>,
#             <Reaction TSULtex at 0x7fbe2b138be0>,
#             <Reaction TTRCYCtex at 0x7fbe2b0cfac0>,
#             <Reaction TUNGStex at 0x7fbe2b0e3f70>,
#             <Reaction TYMtex at 0x7fbe2b0e3bb0>,
#             <Reaction TYRPtex at 0x7fbe2b0f7fa0>,
#             <Reaction TYRtex at 0x7fbe2b183c10>,
#             <Reaction UACGAMtex at 0x7fbe2b1be1f0>,
#             <Reaction UDPACGALtex at 0x7fbe2b167d00>,
#             <Reaction UDPGALtex at 0x7fbe2b17af10>,
#             <Reaction UDPGLCURtex at 0x7fbe2b10efa0>,
#             <Reaction UDPGtex at 0x7fbe2b167f10>,
#             <Reaction UMPtex at 0x7fbe2b0cfdf0>,
#             <Reaction URAtex at 0x7fbe2b0e3be0>,
#             <Reaction UREAtex at 0x7fbe2b0f7f10>,
#             <Reaction VALtex at 0x7fbe2b0e3760>,
#             <Reaction XANtex at 0x7fbe2b08b970>,
#             <Reaction XMPtex at 0x7fbe2b0a3f40>,
#             <Reaction XTSNtex at 0x7fbe2b0b73d0>,
#             <Reaction XYLUtex at 0x7fbe2b04cee0>,
#             <Reaction XYLtex at 0x7fbe2b060ac0>,
#             <Reaction Zn2tex at 0x7fbe2b076670>}),
#  'OmpF': frozenset({<Reaction 12PPDRtex at 0x7fbe2bf9bc10>,
#             <Reaction 12PPDStex at 0x7fbe2bf9bca0>,
#             <Reaction 23CAMPtex at 0x7fbe2bf9bfd0>,
#             <Reaction 23CCMPtex at 0x7fbe2bf9bdc0>,
#             <Reaction 23CGMPtex at 0x7fbe2bfaa460>,
#             <Reaction 23CUMPtex at 0x7fbe2bf9b910>,
#             <Reaction 23DAPPAtex at 0x7fbe2bf9b970>,
#             <Reaction 26DAHtex at 0x7fbe2bfb88e0>,
#             <Reaction 34dhpactex at 0x7fbe2bf73ee0>,
#             <Reaction 3AMPtex at 0x7fbe2bf73f70>,
#             <Reaction 3CMPtex at 0x7fbe2bf73b50>,
#             <Reaction 3GMPtex at 0x7fbe2bf73f10>,
#             <Reaction 3HPPtex at 0x7fbe2bf0fd60>,
#             <Reaction 3PEPTtex at 0x7fbe2bee1b50>,
#             <Reaction 3UMPtex at 0x7fbe2bee1dc0>,
#             <Reaction 3hoxpactex at 0x7fbe2b021c10>,
#             <Reaction 4HOXPACDtex at 0x7fbe2bef08e0>,
#             <Reaction 4PEPTtex at 0x7fbe2befef70>,
#             <Reaction 4hoxpactex at 0x7fbe2b021cd0>,
#             <Reaction 5DGLCNtex at 0x7fbe2be8c520>,
#             <Reaction 5MTRtex at 0x7fbe2be8cf70>,
#             <Reaction 6APAt1 at 0x7fbe2b036820>,
#             <Reaction ABUTtex at 0x7fbe2bf1bf40>,
#             <Reaction ACACtex at 0x7fbe2bf37fa0>,
#             <Reaction ACALDtex at 0x7fbe2bec7b50>,
#             <Reaction ACGAL1Ptex at 0x7fbe2bec7f70>,
#             <Reaction ACGALtex at 0x7fbe2bee1a60>,
#             <Reaction ACGAM1Ptex at 0x7fbe2bee1fd0>,
#             <Reaction ACGAtex at 0x7fbe2bef0eb0>,
#             <Reaction ACMANAtex at 0x7fbe2befef10>,
#             <Reaction ACMUMtex at 0x7fbe2be8ce80>,
#             <Reaction ACNAMtex at 0x7fbe2befeca0>,
#             <Reaction ACSERtex at 0x7fbe2beb6d60>,
#             <Reaction ACtex at 0x7fbe2be56c40>,
#             <Reaction ADEtex at 0x7fbe2be64e80>,
#             <Reaction AGMtex at 0x7fbe2bdd4e80>,
#             <Reaction AKGtex at 0x7fbe2be47f10>,
#             <Reaction ALAALAtex at 0x7fbe2beb6730>,
#             <Reaction ALAtex at 0x7fbe2be74f10>,
#             <Reaction ALLTNtex at 0x7fbe2be23670>,
#             <Reaction ALLtex at 0x7fbe2be34c10>,
#             <Reaction AMPtex at 0x7fbe2bde3ee0>,
#             <Reaction ANHGMtex at 0x7fbe2bde3970>,
#             <Reaction ARBTtex at 0x7fbe2bc5ba90>,
#             <Reaction ARBtex at 0x7fbe2bc1ef10>,
#             <Reaction ARGtex at 0x7fbe2bb63eb0>,
#             <Reaction ASCBtex at 0x7fbe2bb1bb80>,
#             <Reaction ASNtex at 0x7fbe2ba5cdc0>,
#             <Reaction ASO3tex at 0x7fbe2ba03670>,
#             <Reaction ASPtex at 0x7fbe2bde3c70>,
#             <Reaction BALAtex at 0x7fbe2bd93fa0>,
#             <Reaction BTNtex at 0x7fbe2bda3f40>,
#             <Reaction BUTSO3tex at 0x7fbe2bdb2580>,
#             <Reaction BUTtex at 0x7fbe2bd52f70>,
#             <Reaction CA2tex at 0x7fbe2bd5ecd0>,
#             <Reaction CD2tex at 0x7fbe2bd10910>,
#             <Reaction CGLYtex at 0x7fbe2bda3fa0>,
#             <Reaction CHLtex at 0x7fbe2bda3f10>,
#             <Reaction CHTBStex at 0x7fbe2bdbeca0>,
#             <Reaction CITtex at 0x7fbe2bdbee20>,
#             <Reaction CLBtex at 0x7fbe2b060ee0>,
#             <Reaction CLtex at 0x7fbe2bd7efd0>,
#             <Reaction CMPtex at 0x7fbe2bd7ef70>,
#             <Reaction CMtex at 0x7fbe2bd6caf0>,
#             <Reaction CO2tex at 0x7fbe2bd10f40>,
#             <Reaction COBALT2tex at 0x7fbe2bd1fd30>,
#             <Reaction CRNDtex at 0x7fbe2bcd0d00>,
#             <Reaction CRNtex at 0x7fbe2bcdeb20>,
#             <Reaction CSNtex at 0x7fbe2bcefdf0>,
#             <Reaction CU2tex at 0x7fbe2bc8de80>,
#             <Reaction CUtex at 0x7fbe2bc9eaf0>,
#             <Reaction CYANtex at 0x7fbe2bc9ed60>,
#             <Reaction CYNTtex at 0x7fbe2bcadc70>,
#             <Reaction CYSDtex at 0x7fbe2bcaddc0>,
#             <Reaction CYStex at 0x7fbe2bc4cdc0>,
#             <Reaction CYTDtex at 0x7fbe2bc5be50>,
#             <Reaction DALAtex at 0x7fbe2bcd0c40>,
#             <Reaction DAMPtex at 0x7fbe2bcefe20>,
#             <Reaction DAPtex at 0x7fbe2bcfefd0>,
#             <Reaction DARBtex at 0x7fbe2af6bdc0>,
#             <Reaction DCAtex at 0x7fbe2bc9ebb0>,
#             <Reaction DCMPtex at 0x7fbe2bc9ea90>,
#             <Reaction DDGLCNtex at 0x7fbe2bcad8e0>,
#             <Reaction DGMPtex at 0x7fbe2bcbcd60>,
#             <Reaction DGSNtex at 0x7fbe2bc4cc70>,
#             <Reaction DHAtex at 0x7fbe2bc5bca0>,
#             <Reaction DIMPtex at 0x7fbe2bc0af40>,
#             <Reaction DINStex at 0x7fbe2bc6ca60>,
#             <Reaction DMSOtex at 0x7fbe2bc33e80>,
#             <Reaction DMStex at 0x7fbe2bc33a30>,
#             <Reaction DOPAtex at 0x7fbe2bbc6eb0>,
#             <Reaction DOXRBCNtex at 0x7fbe2bbc6f10>,
#             <Reaction DSERtex at 0x7fbe2bbea7c0>,
#             <Reaction DTMPtex at 0x7fbe2bbfed90>,
#             <Reaction DUMPtex at 0x7fbe2bbfeaf0>,
#             <Reaction D_LACtex at 0x7fbe2bc7bdc0>,
#             <Reaction ETHAtex at 0x7fbe2bb92ee0>,
#             <Reaction ETHSO3tex at 0x7fbe2bb50dc0>,
#             <Reaction ETOHtex at 0x7fbe2bbfefd0>,
#             <Reaction F6Ptex at 0x7fbe2bb63c10>,
#             <Reaction FALDtex at 0x7fbe2bb1bf10>,
#             <Reaction FE2tex at 0x7fbe2bae8fa0>,
#             <Reaction FE3tex at 0x7fbe2bab5d00>,
#             <Reaction FORtex at 0x7fbe2baa3d90>,
#             <Reaction FRULYStex at 0x7fbe2ba49a60>,
#             <Reaction FRUURtex at 0x7fbe2ba49d90>,
#             <Reaction FRUtex at 0x7fbe2ba5cdf0>,
#             <Reaction FUCtex at 0x7fbe2ba5c8e0>,
#             <Reaction FUMtex at 0x7fbe2ba6de80>,
#             <Reaction FUSAtex at 0x7fbe2ba6dfa0>,
#             <Reaction G1Ptex at 0x7fbe2ba16eb0>,
#             <Reaction G3PCtex at 0x7fbe2ba16ee0>,
#             <Reaction G3PEtex at 0x7fbe2ba28d90>,
#             <Reaction G3PGtex at 0x7fbe31783a60>,
#             <Reaction G3PItex at 0x7fbe3179c5b0>,
#             <Reaction G3PStex at 0x7fbe3179c280>,
#             <Reaction G6Ptex at 0x7fbe31753e50>,
#             <Reaction GAL1Ptex at 0x7fbe3176ba90>,
#             <Reaction GALAMtex at 0x7fbe2b00b5e0>,
#             <Reaction GALBDtex at 0x7fbe31735eb0>,
#             <Reaction GALCTNLtex at 0x7fbe31778130>,
#             <Reaction GALCTNtex at 0x7fbe31699850>,
#             <Reaction GALCTtex at 0x7fbe31692c70>,
#             <Reaction GALTtex at 0x7fbe31699c40>,
#             <Reaction GALURtex at 0x7fbe316e7f70>,
#             <Reaction GALtex at 0x7fbe308bb250>,
#             <Reaction GAMAN6Ptex at 0x7fbe308c4fd0>,
#             <Reaction GAMtex at 0x7fbe30931160>,
#             <Reaction GBBTNtex at 0x7fbe30881b50>,
#             <Reaction GDPtex at 0x7fbe30839e80>,
#             <Reaction GLCNtex at 0x7fbe3172e5e0>,
#             <Reaction GLCRtex at 0x7fbe316cf370>,
#             <Reaction GLCUR1Ptex at 0x7fbe316eeee0>,
#             <Reaction GLCURtex at 0x7fbe316a2550>,
#             <Reaction GLCtex_copy1 at 0x7fbe31760790>,
#             <Reaction GLNtex at 0x7fbe308cfeb0>,
#             <Reaction GLUtex at 0x7fbe308afcd0>,
#             <Reaction GLYALDtex at 0x7fbe30857f10>,
#             <Reaction GLYBtex at 0x7fbe30367820>,
#             <Reaction GLYC2Ptex at 0x7fbe3088ca00>,
#             <Reaction GLYC3Ptex at 0x7fbe3315c160>,
#             <Reaction GLYCAtex at 0x7fbe308c4d60>,
#             <Reaction GLYCLTtex at 0x7fbe2b8ce610>,
#             <Reaction GLYCtex at 0x7fbe2b846eb0>,
#             <Reaction GLYtex at 0x7fbe2b7eabb0>,
#             <Reaction GMPtex at 0x7fbe2b71bbb0>,
#             <Reaction GSNtex at 0x7fbe2b5decd0>,
#             <Reaction GTHOXtex at 0x7fbe2b59eeb0>,
#             <Reaction GTHRDtex at 0x7fbe2b508f10>,
#             <Reaction GTPtex at 0x7fbe2b49dd60>,
#             <Reaction H2O2tex at 0x7fbe2ba3b4f0>,
#             <Reaction H2Otex at 0x7fbe2b9235e0>,
#             <Reaction H2Stex at 0x7fbe2b937ee0>,
#             <Reaction H2tex at 0x7fbe2b937370>,
#             <Reaction HCINNMtex at 0x7fbe2b8f6e20>,
#             <Reaction HG2tex at 0x7fbe2b8a9eb0>,
#             <Reaction HIStex at 0x7fbe2b846880>,
#             <Reaction HOMtex at 0x7fbe2b878f40>,
#             <Reaction HPPPNtex at 0x7fbe2b86fd60>,
#             <Reaction HXAtex at 0x7fbe3086d940>,
#             <Reaction HYXNtex at 0x7fbe2b8ceee0>,
#             <Reaction Htex at 0x7fbe2b937f40>,
#             <Reaction IDONtex at 0x7fbe2b8a09d0>,
#             <Reaction ILEtex at 0x7fbe2b8b2820>,
#             <Reaction IMPtex at 0x7fbe2b8bb850>,
#             <Reaction INDOLEtex at 0x7fbe2b864640>,
#             <Reaction INSTtex at 0x7fbe2b84ed00>,
#             <Reaction ISETACtex at 0x7fbe2b81daf0>,
#             <Reaction Ktex at 0x7fbe2b7c3eb0>,
#             <Reaction LALADGLUtex at 0x7fbe2b7eaf10>,
#             <Reaction LALALGLUtex at 0x7fbe2b7ea880>,
#             <Reaction LCTStex at 0x7fbe2b7feee0>,
#             <Reaction LEUtex at 0x7fbe2b7a5e50>,
#             <Reaction LIPOtex at 0x7fbe2b74bf40>,
#             <Reaction LYStex at 0x7fbe2b7749a0>,
#             <Reaction LYXtex at 0x7fbe2b707b80>,
#             <Reaction L_LACtex_copy1 at 0x7fbe2b7d6ee0>,
#             <Reaction L_LACtex_copy2 at 0x7fbe2b0b7cd0>,
#             <Reaction MALDtex at 0x7fbe2b707f40>,
#             <Reaction MALtex at 0x7fbe2b6c4fd0>,
#             <Reaction MAN6Ptex at 0x7fbe2b6d8a60>,
#             <Reaction MANGLYCtex at 0x7fbe2b71bd00>,
#             <Reaction MANtex at 0x7fbe2b730f70>,
#             <Reaction MELIBtex at 0x7fbe2b6ebfd0>,
#             <Reaction MEOHtex at 0x7fbe2b6fdd60>,
#             <Reaction METDtex at 0x7fbe2b6a9b50>,
#             <Reaction METSOX1tex at 0x7fbe2b6a9be0>,
#             <Reaction METSOX2tex at 0x7fbe2b6a9d90>,
#             <Reaction METtex at 0x7fbe2b651e50>,
#             <Reaction MG2tex at 0x7fbe2b6bd520>,
#             <Reaction MINCYCtex at 0x7fbe2b6ebeb0>,
#             <Reaction MMETtex at 0x7fbe2b694d90>,
#             <Reaction MNLtex at 0x7fbe2b694b50>,
#             <Reaction MNtex at 0x7fbe2b666fa0>,
#             <Reaction MOBDtex at 0x7fbe2b67ec40>,
#             <Reaction MSO3tex at 0x7fbe2b6264c0>,
#             <Reaction N2Otex at 0x7fbe2b5cdf10>,
#             <Reaction NACtex at 0x7fbe2b612f10>,
#             <Reaction NAtex at 0x7fbe2b5f6f40>,
#             <Reaction NH4tex at 0x7fbe2b587fd0>,
#             <Reaction NI2tex at 0x7fbe2b5b0fa0>,
#             <Reaction NMNtex at 0x7fbe2b5b08e0>,
#             <Reaction NO2tex at 0x7fbe2b572f10>,
#             <Reaction NO3tex at 0x7fbe2b587d90>,
#             <Reaction NOtex at 0x7fbe2b587cd0>,
#             <Reaction O2Stex at 0x7fbe2b489df0>,
#             <Reaction O2tex at 0x7fbe2b489970>,
#             <Reaction OCTAtex at 0x7fbe2b51beb0>,
#             <Reaction ORNtex at 0x7fbe2b4f3ee0>,
#             <Reaction OROTtex at 0x7fbe2b489c10>,
#             <Reaction PACALDtex at 0x7fbe2b4b2d00>,
#             <Reaction PACt1 at 0x7fbe2b036b20>,
#             <Reaction PEAMNtex at 0x7fbe2b49daf0>,
#             <Reaction PENGt1 at 0x7fbe2b036f10>,
#             <Reaction PHEtex at 0x7fbe2b391670>,
#             <Reaction PItex at 0x7fbe2b3ab970>,
#             <Reaction PNTOtex at 0x7fbe2b076880>,
#             <Reaction PPALtex at 0x7fbe2b021f40>,
#             <Reaction PPAtex at 0x7fbe2b021fd0>,
#             <Reaction PPPNtex at 0x7fbe2aff4f40>,
#             <Reaction PPTtex at 0x7fbe2af9b9a0>,
#             <Reaction PROGLYtex at 0x7fbe2b391ac0>,
#             <Reaction PROtex at 0x7fbe2b3abf40>,
#             <Reaction PSCLYStex at 0x7fbe2b3abc70>,
#             <Reaction PSERtex at 0x7fbe2b354f70>,
#             <Reaction PTRCtex at 0x7fbe2b32bd90>,
#             <Reaction PYDAMtex at 0x7fbe2b2d3940>,
#             <Reaction PYDXNtex at 0x7fbe2b2d3e80>,
#             <Reaction PYDXtex at 0x7fbe2b2d3a90>,
#             <Reaction PYRtex at 0x7fbe2b340fd0>,
#             <Reaction QUIN2tex at 0x7fbe2b36ab20>,
#             <Reaction R5Ptex at 0x7fbe2b37ffa0>,
#             <Reaction RAFFtex at 0x7fbe2b00bf40>,
#             <Reaction RIBtex at 0x7fbe2b32beb0>,
#             <Reaction RMNtex at 0x7fbe2b315760>,
#             <Reaction SALCNtex at 0x7fbe2b0768e0>,
#             <Reaction SBTtex at 0x7fbe2b2b6c40>,
#             <Reaction SELtex at 0x7fbe2b25ec10>,
#             <Reaction SERtex at 0x7fbe2b230e80>,
#             <Reaction SKMtex at 0x7fbe2b1d9fd0>,
#             <Reaction SLNTtex at 0x7fbe2b1d9e20>,
#             <Reaction SO2tex at 0x7fbe2b1edf40>,
#             <Reaction SO3tex at 0x7fbe2b1edeb0>,
#             <Reaction SO4tex at 0x7fbe2b1d9dc0>,
#             <Reaction SPMDtex at 0x7fbe2b2e7e20>,
#             <Reaction SUCCtex at 0x7fbe2b249ee0>,
#             <Reaction SUCRtex at 0x7fbe2b273a60>,
#             <Reaction SULFACtex at 0x7fbe2b207850>,
#             <Reaction TARTRDtex at 0x7fbe2b21cb80>,
#             <Reaction TARTRtex at 0x7fbe2b21cfd0>,
#             <Reaction TAURtex at 0x7fbe2b230d30>,
#             <Reaction TCYNTtex at 0x7fbe2b1c3d90>,
#             <Reaction THMDtex at 0x7fbe2b183d60>,
#             <Reaction THMtex at 0x7fbe2b183670>,
#             <Reaction THRPtex at 0x7fbe2b194e20>,
#             <Reaction THRtex at 0x7fbe2b1aa9a0>,
#             <Reaction THYMtex at 0x7fbe2b1aabe0>,
#             <Reaction TMAOtex at 0x7fbe2b1bea90>,
#             <Reaction TMAtex at 0x7fbe2b1bec70>,
#             <Reaction TREtex at 0x7fbe2b10edf0>,
#             <Reaction TRPtex at 0x7fbe2b138af0>,
#             <Reaction TSULtex at 0x7fbe2b138be0>,
#             <Reaction TTRCYCtex at 0x7fbe2b0cfac0>,
#             <Reaction TUNGStex at 0x7fbe2b0e3f70>,
#             <Reaction TYMtex at 0x7fbe2b0e3bb0>,
#             <Reaction TYRPtex at 0x7fbe2b0f7fa0>,
#             <Reaction TYRtex at 0x7fbe2b183c10>,
#             <Reaction UACGAMtex at 0x7fbe2b1be1f0>,
#             <Reaction UDPACGALtex at 0x7fbe2b167d00>,
#             <Reaction UDPGALtex at 0x7fbe2b17af10>,
#             <Reaction UDPGLCURtex at 0x7fbe2b10efa0>,
#             <Reaction UDPGtex at 0x7fbe2b167f10>,
#             <Reaction UMPtex at 0x7fbe2b0cfdf0>,
#             <Reaction URAtex at 0x7fbe2b0e3be0>,
#             <Reaction UREAtex at 0x7fbe2b0f7f10>,
#             <Reaction VALtex at 0x7fbe2b0e3760>,
#             <Reaction XANtex at 0x7fbe2b08b970>,
#             <Reaction XMPtex at 0x7fbe2b0a3f40>,
#             <Reaction XTSNtex at 0x7fbe2b0b73d0>,
#             <Reaction XYLUtex at 0x7fbe2b04cee0>,
#             <Reaction XYLtex at 0x7fbe2b060ac0>,
#             <Reaction Zn2tex at 0x7fbe2b076670>}),
#  'OmpN': frozenset({<Reaction 12PPDRtex at 0x7fbe2bf9bc10>,
#             <Reaction 12PPDStex at 0x7fbe2bf9bca0>,
#             <Reaction 23CAMPtex at 0x7fbe2bf9bfd0>,
#             <Reaction 23CCMPtex at 0x7fbe2bf9bdc0>,
#             <Reaction 23CGMPtex at 0x7fbe2bfaa460>,
#             <Reaction 23CUMPtex at 0x7fbe2bf9b910>,
#             <Reaction 23DAPPAtex at 0x7fbe2bf9b970>,
#             <Reaction 26DAHtex at 0x7fbe2bfb88e0>,
#             <Reaction 34dhpactex at 0x7fbe2bf73ee0>,
#             <Reaction 3AMPtex at 0x7fbe2bf73f70>,
#             <Reaction 3CMPtex at 0x7fbe2bf73b50>,
#             <Reaction 3GMPtex at 0x7fbe2bf73f10>,
#             <Reaction 3HPPtex at 0x7fbe2bf0fd60>,
#             <Reaction 3PEPTtex at 0x7fbe2bee1b50>,
#             <Reaction 3UMPtex at 0x7fbe2bee1dc0>,
#             <Reaction 3hoxpactex at 0x7fbe2b021c10>,
#             <Reaction 4HOXPACDtex at 0x7fbe2bef08e0>,
#             <Reaction 4PEPTtex at 0x7fbe2befef70>,
#             <Reaction 4hoxpactex at 0x7fbe2b021cd0>,
#             <Reaction 5DGLCNtex at 0x7fbe2be8c520>,
#             <Reaction 5MTRtex at 0x7fbe2be8cf70>,
#             <Reaction 6APAt1 at 0x7fbe2b036820>,
#             <Reaction ABUTtex at 0x7fbe2bf1bf40>,
#             <Reaction ACACtex at 0x7fbe2bf37fa0>,
#             <Reaction ACALDtex at 0x7fbe2bec7b50>,
#             <Reaction ACGAL1Ptex at 0x7fbe2bec7f70>,
#             <Reaction ACGALtex at 0x7fbe2bee1a60>,
#             <Reaction ACGAM1Ptex at 0x7fbe2bee1fd0>,
#             <Reaction ACGAtex at 0x7fbe2bef0eb0>,
#             <Reaction ACMANAtex at 0x7fbe2befef10>,
#             <Reaction ACMUMtex at 0x7fbe2be8ce80>,
#             <Reaction ACSERtex at 0x7fbe2beb6d60>,
#             <Reaction ACtex at 0x7fbe2be56c40>,
#             <Reaction ADEtex at 0x7fbe2be64e80>,
#             <Reaction AGMtex at 0x7fbe2bdd4e80>,
#             <Reaction AKGtex at 0x7fbe2be47f10>,
#             <Reaction ALAALAtex at 0x7fbe2beb6730>,
#             <Reaction ALAtex at 0x7fbe2be74f10>,
#             <Reaction ALLTNtex at 0x7fbe2be23670>,
#             <Reaction ALLtex at 0x7fbe2be34c10>,
#             <Reaction AMPtex at 0x7fbe2bde3ee0>,
#             <Reaction ANHGMtex at 0x7fbe2bde3970>,
#             <Reaction ARBTtex at 0x7fbe2bc5ba90>,
#             <Reaction ARBtex at 0x7fbe2bc1ef10>,
#             <Reaction ARGtex at 0x7fbe2bb63eb0>,
#             <Reaction ASCBtex at 0x7fbe2bb1bb80>,
#             <Reaction ASNtex at 0x7fbe2ba5cdc0>,
#             <Reaction ASO3tex at 0x7fbe2ba03670>,
#             <Reaction ASPtex at 0x7fbe2bde3c70>,
#             <Reaction BALAtex at 0x7fbe2bd93fa0>,
#             <Reaction BTNtex at 0x7fbe2bda3f40>,
#             <Reaction BUTSO3tex at 0x7fbe2bdb2580>,
#             <Reaction BUTtex at 0x7fbe2bd52f70>,
#             <Reaction CA2tex at 0x7fbe2bd5ecd0>,
#             <Reaction CD2tex at 0x7fbe2bd10910>,
#             <Reaction CGLYtex at 0x7fbe2bda3fa0>,
#             <Reaction CHLtex at 0x7fbe2bda3f10>,
#             <Reaction CHTBStex at 0x7fbe2bdbeca0>,
#             <Reaction CITtex at 0x7fbe2bdbee20>,
#             <Reaction CLBtex at 0x7fbe2b060ee0>,
#             <Reaction CLtex at 0x7fbe2bd7efd0>,
#             <Reaction CMPtex at 0x7fbe2bd7ef70>,
#             <Reaction CMtex at 0x7fbe2bd6caf0>,
#             <Reaction CO2tex at 0x7fbe2bd10f40>,
#             <Reaction COBALT2tex at 0x7fbe2bd1fd30>,
#             <Reaction CRNDtex at 0x7fbe2bcd0d00>,
#             <Reaction CRNtex at 0x7fbe2bcdeb20>,
#             <Reaction CSNtex at 0x7fbe2bcefdf0>,
#             <Reaction CU2tex at 0x7fbe2bc8de80>,
#             <Reaction CUtex at 0x7fbe2bc9eaf0>,
#             <Reaction CYANtex at 0x7fbe2bc9ed60>,
#             <Reaction CYNTtex at 0x7fbe2bcadc70>,
#             <Reaction CYSDtex at 0x7fbe2bcaddc0>,
#             <Reaction CYStex at 0x7fbe2bc4cdc0>,
#             <Reaction CYTDtex at 0x7fbe2bc5be50>,
#             <Reaction DALAtex at 0x7fbe2bcd0c40>,
#             <Reaction DAMPtex at 0x7fbe2bcefe20>,
#             <Reaction DAPtex at 0x7fbe2bcfefd0>,
#             <Reaction DARBtex at 0x7fbe2af6bdc0>,
#             <Reaction DCAtex at 0x7fbe2bc9ebb0>,
#             <Reaction DCMPtex at 0x7fbe2bc9ea90>,
#             <Reaction DDGLCNtex at 0x7fbe2bcad8e0>,
#             <Reaction DGMPtex at 0x7fbe2bcbcd60>,
#             <Reaction DGSNtex at 0x7fbe2bc4cc70>,
#             <Reaction DHAtex at 0x7fbe2bc5bca0>,
#             <Reaction DIMPtex at 0x7fbe2bc0af40>,
#             <Reaction DINStex at 0x7fbe2bc6ca60>,
#             <Reaction DMSOtex at 0x7fbe2bc33e80>,
#             <Reaction DMStex at 0x7fbe2bc33a30>,
#             <Reaction DOPAtex at 0x7fbe2bbc6eb0>,
#             <Reaction DOXRBCNtex at 0x7fbe2bbc6f10>,
#             <Reaction DSERtex at 0x7fbe2bbea7c0>,
#             <Reaction DTMPtex at 0x7fbe2bbfed90>,
#             <Reaction DUMPtex at 0x7fbe2bbfeaf0>,
#             <Reaction D_LACtex at 0x7fbe2bc7bdc0>,
#             <Reaction ETHAtex at 0x7fbe2bb92ee0>,
#             <Reaction ETHSO3tex at 0x7fbe2bb50dc0>,
#             <Reaction ETOHtex at 0x7fbe2bbfefd0>,
#             <Reaction F6Ptex at 0x7fbe2bb63c10>,
#             <Reaction FALDtex at 0x7fbe2bb1bf10>,
#             <Reaction FE2tex at 0x7fbe2bae8fa0>,
#             <Reaction FE3tex at 0x7fbe2bab5d00>,
#             <Reaction FORtex at 0x7fbe2baa3d90>,
#             <Reaction FRULYStex at 0x7fbe2ba49a60>,
#             <Reaction FRUURtex at 0x7fbe2ba49d90>,
#             <Reaction FRUtex at 0x7fbe2ba5cdf0>,
#             <Reaction FUCtex at 0x7fbe2ba5c8e0>,
#             <Reaction FUMtex at 0x7fbe2ba6de80>,
#             <Reaction FUSAtex at 0x7fbe2ba6dfa0>,
# ...
#  'OmpG': frozenset({<Reaction H2Otex at 0x7fbe2b9235e0>}),
#  'Pgm': frozenset({<Reaction PGMT at 0x7fbe2b40aa00>}),
#  'OmpA': frozenset({<Reaction H2Otex at 0x7fbe2b9235e0>}),
#  'MaeA': frozenset({<Reaction ME1 at 0x7fbe2b6ebfa0>}),
#  'PgpA': frozenset({<Reaction PGPP120 at 0x7fbe2b43bd90>,
#             <Reaction PGPP120pp at 0x7fbe2b43bfa0>,
#             <Reaction PGPP140 at 0x7fbe2b43bd00>,
#             <Reaction PGPP140pp at 0x7fbe2b3d0fa0>,
#             <Reaction PGPP141 at 0x7fbe2b3d0f40>,
#             <Reaction PGPP141pp at 0x7fbe2b3d0cd0>,
#             <Reaction PGPP160 at 0x7fbe2b3d0f70>,
#             <Reaction PGPP160pp at 0x7fbe2b3d0d60>,
#             <Reaction PGPP161 at 0x7fbe2b3d0eb0>,
#             <Reaction PGPP161pp at 0x7fbe2b3d0d30>,
#             <Reaction PGPP180 at 0x7fbe2b3d0a00>,
#             <Reaction PGPP180pp at 0x7fbe2b3e7d00>,
#             <Reaction PGPP181 at 0x7fbe2b3e7340>,
#             <Reaction PGPP181pp at 0x7fbe2b3d0ee0>}),
#  'MaeB': frozenset({<Reaction ME2 at 0x7fbe2b6fdf10>}),
#  'PgsA': frozenset({<Reaction PGSA120 at 0x7fbe2b3d0b80>,
#             <Reaction PGSA140 at 0x7fbe2b3d09d0>,
#             <Reaction PGSA141 at 0x7fbe2b3e7fd0>,
#             <Reaction PGSA160 at 0x7fbe2b3fca90>,
#             <Reaction PGSA161 at 0x7fbe2b3fcca0>,
#             <Reaction PGSA180 at 0x7fbe2b3fccd0>,
#             <Reaction PGSA181 at 0x7fbe2b3fcaf0>}),
#  'IspG': frozenset({<Reaction MECDPDH2 at 0x7fbe2b0a3e50>,
#             <Reaction MECDPDH5 at 0x7fbe2b6ebb20>}),
#  'AqpZ': frozenset({<Reaction H2Otpp at 0x7fbe2b92bd60>}),
#  'CcmB': frozenset({<Reaction PHEMEabcpp at 0x7fbe2b391be0>}),
#  'UbiA': frozenset({<Reaction HBZOPT at 0x7fbe2b8d9c40>}),
#  'CcmE': frozenset({<Reaction PHEMEabcpp at 0x7fbe2b391be0>}),
#  'MhpT': frozenset({<Reaction HCINNMt2rpp at 0x7fbe2b8e3d60>,
#             <Reaction HPPPNt2rpp at 0x7fbe2b846b20>}),
#  'CynT': frozenset({<Reaction HCO3E at 0x7fbe2b8e3d90>}),
#  'IspF': frozenset({<Reaction MECDPS at 0x7fbe2b6fdf40>}),
#  'MelB': frozenset({<Reaction MELIBt2pp at 0x7fbe2b6fdfa0>}),
#  'CcmC': frozenset({<Reaction PHEMEabcpp at 0x7fbe2b391be0>}),
#  'IspD': frozenset({<Reaction MEPCT at 0x7fbe2b694eb0>}),
#  'Can': frozenset({<Reaction HCO3E at 0x7fbe2b8e3d90>}),
#  'CcmD': frozenset({<Reaction PHEMEabcpp at 0x7fbe2b391be0>}),
#  'CyoE': frozenset({<Reaction HEMEOS at 0x7fbe2b88bd00>}),
#  'MetK': frozenset({<Reaction METAT at 0x7fbe2b694700>}),
#  'CcmA': frozenset({<Reaction PHEMEabcpp at 0x7fbe2b391be0>}),
#  'MetN': frozenset({<Reaction METDabcpp at 0x7fbe2b694c70>,
#             <Reaction METabcpp at 0x7fbe2b651f10>}),
#  'PheS': frozenset({<Reaction PHETRS at 0x7fbe2b391a30>}),
#  'MetI': frozenset({<Reaction METDabcpp at 0x7fbe2b694c70>,
#             <Reaction METabcpp at 0x7fbe2b651f10>}),
#  'RfaP': frozenset({<Reaction HEPK1 at 0x7fbe2b88beb0>,
#             <Reaction HEPKA1 at 0x7fbe2af9b8b0>,
#             <Reaction HEPKB1 at 0x7fbe2af41d30>}),
#  'PheT': frozenset({<Reaction PHETRS at 0x7fbe2b391a30>}),
#  'PheP': frozenset({<Reaction PHEt2rpp at 0x7fbe2b3e7df0>,
#             <Reaction TYRt2rpp at 0x7fbe2b183dc0>}),
#  'RfaY': frozenset({<Reaction HEPK2 at 0x7fbe2b8e3730>,
#             <Reaction HEPKA2 at 0x7fbe2af9baf0>,
#             <Reaction HEPKB2 at 0x7fbe2af418e0>}),
#  'RfaC': frozenset({<Reaction HEPT1 at 0x7fbe2b895eb0>,
#             <Reaction HEPTA1 at 0x7fbe2af9bf10>,
#             <Reaction HEPTB1 at 0x7fbe2af41df0>}),
#  'MetQ': frozenset({<Reaction METDabcpp at 0x7fbe2b694c70>,
#             <Reaction METabcpp at 0x7fbe2b651f10>}),
#  'MetE': frozenset({<Reaction METS at 0x7fbe2b6a9c40>}),
#  'YddG': frozenset({<Reaction PHEt2rpp at 0x7fbe2b3e7df0>,
#             <Reaction TRPt2rpp at 0x7fbe2b138820>,
#             <Reaction TYRt2rpp at 0x7fbe2b183dc0>}),
#  'RfaF': frozenset({<Reaction HEPT2 at 0x7fbe2b895e80>,
#             <Reaction HEPTA2 at 0x7fbe2af9bcd0>,
#             <Reaction HEPTB2 at 0x7fbe2af41e50>}),
#  'PitA': frozenset({<Reaction PIt2rpp at 0x7fbe2b3abe80>}),
#  'RfaQ': frozenset({<Reaction HEPT3 at 0x7fbe2b895b80>,
#             <Reaction HEPTA3 at 0x7fbe2aff4460>,
#             <Reaction HEPTB3 at 0x7fbe2af9bdf0>}),
#  'MetH': frozenset({<Reaction METS at 0x7fbe2b6a9c40>}),
#  'PitB': frozenset({<Reaction PIt2rpp at 0x7fbe2b3abe80>}),
#  'MsrA': frozenset({<Reaction METSOXR1 at 0x7fbe2b6a9fd0>}),
#  'MsrB': frozenset({<Reaction METSOXR2 at 0x7fbe2b6bde50>}),
#  'ThiM': frozenset({<Reaction HETZK at 0x7fbe2b8a0940>}),
#  'PstA': frozenset({<Reaction PIuabcpp at 0x7fbe2b340d60>}),
#  'MetG': frozenset({<Reaction METTRS at 0x7fbe2b6517f0>}),
#  'PstB': frozenset({<Reaction PIuabcpp at 0x7fbe2b340d60>}),
#  'MgtA': frozenset({<Reaction MG2uabcpp at 0x7fbe2b651970>,
#             <Reaction NI2uabcpp at 0x7fbe2b5b0580>}),
#  'MgsA': frozenset({<Reaction MGSA at 0x7fbe2b666a30>}),
#  'PstS': frozenset({<Reaction PIuabcpp at 0x7fbe2b340d60>}),
#  'MalZ': frozenset({<Reaction MLTG1 at 0x7fbe2b6fdf70>,
#             <Reaction MLTG2 at 0x7fbe2b6fde50>,
#             <Reaction MLTG3 at 0x7fbe2b694f40>,
#             <Reaction MLTG4 at 0x7fbe2b694c40>,
#             <Reaction MLTG5 at 0x7fbe2b694df0>}),
#  'PstC': frozenset({<Reaction PIuabcpp at 0x7fbe2b340d60>}),
#  'Glk': frozenset({<Reaction HEX1 at 0x7fbe2b895f40>}),
#  'PldA': frozenset({<Reaction PLIPA1A120pp at 0x7fbe2b3abcd0>,
#             <Reaction PLIPA1A140pp at 0x7fbe2b340940>,
#             <Reaction PLIPA1A141pp at 0x7fbe2b340d00>,
#             <Reaction PLIPA1A160pp at 0x7fbe2b340c10>,
#             <Reaction PLIPA1A161pp at 0x7fbe2b354a60>,
#             <Reaction PLIPA1A180pp at 0x7fbe2b40afd0>,
#             <Reaction PLIPA1A181pp at 0x7fbe2b43ba90>,
#             <Reaction PLIPA1E120pp at 0x7fbe2b40ae80>,
#             <Reaction PLIPA1E140pp at 0x7fbe2b3d05b0>,
#             <Reaction PLIPA1E141pp at 0x7fbe2b3e7b20>,
#             <Reaction PLIPA1E160pp at 0x7fbe2b391c10>,
#             <Reaction PLIPA1E161pp at 0x7fbe2b3abf70>,
#             <Reaction PLIPA1E180pp at 0x7fbe2b340f70>,
#             <Reaction PLIPA1E181pp at 0x7fbe2b3546d0>,
#             <Reaction PLIPA1G120pp at 0x7fbe2b354ee0>,
#             <Reaction PLIPA1G140pp at 0x7fbe2b36aa30>,
#             <Reaction PLIPA1G141pp at 0x7fbe2b37fd90>,
#             <Reaction PLIPA1G160pp at 0x7fbe2b315fa0>,
#             <Reaction PLIPA1G161pp at 0x7fbe2b33fd60>,
#             <Reaction PLIPA1G180pp at 0x7fbe2b33fc70>,
#             <Reaction PLIPA1G181pp at 0x7fbe2b3154f0>,
#             <Reaction PLIPA2A120pp at 0x7fbe2b2fba00>,
#             <Reaction PLIPA2A140pp at 0x7fbe2b2a2d60>,
#             <Reaction PLIPA2A141pp at 0x7fbe2b2b6bb0>,
#             <Reaction PLIPA2A160pp at 0x7fbe2b28f4f0>,
#             <Reaction PLIPA2A161pp at 0x7fbe2b249970>,
#             <Reaction PLIPA2A180pp at 0x7fbe2b249e80>,
#             <Reaction PLIPA2A181pp at 0x7fbe2b273f70>,
#             <Reaction PLIPA2E120pp at 0x7fbe2b21c700>,
#             <Reaction PLIPA2E140pp at 0x7fbe2b230fa0>,
#             <Reaction PLIPA2E141pp at 0x7fbe2b1c3d30>,
#             <Reaction PLIPA2E160pp at 0x7fbe2b1c3eb0>,
#             <Reaction PLIPA2E161pp at 0x7fbe2b183e80>,
#             <Reaction PLIPA2E180pp at 0x7fbe2b183f40>,
#             <Reaction PLIPA2E181pp at 0x7fbe2b1aae80>,
#             <Reaction PLIPA2G120pp at 0x7fbe2b1be9d0>,
#             <Reaction PLIPA2G140pp at 0x7fbe2b167f70>,
#             <Reaction PLIPA2G141pp at 0x7fbe2b10e6a0>,
#             <Reaction PLIPA2G160pp at 0x7fbe2b124d00>,
#             <Reaction PLIPA2G161pp at 0x7fbe2b138eb0>,
#             <Reaction PLIPA2G180pp at 0x7fbe2b0cfe50>,
#             <Reaction PLIPA2G181pp at 0x7fbe2b0f7e50>}),
#  'MltC': frozenset({<Reaction MLTGY1pp at 0x7fbe2b694ee0>,
#             <Reaction MLTGY2pp at 0x7fbe2b6a9820>,
#             <Reaction MLTGY3pp at 0x7fbe2b6a9880>,
#             <Reaction MLTGY4pp at 0x7fbe2b694d60>}),
#  'CpsG': frozenset({<Reaction PMANM at 0x7fbe2b0f7f70>}),
#  'EmtA': frozenset({<Reaction MLTGY1pp at 0x7fbe2b694ee0>,
#             <Reaction MLTGY2pp at 0x7fbe2b6a9820>,
#             <Reaction MLTGY3pp at 0x7fbe2b6a9880>,
#             <Reaction MLTGY4pp at 0x7fbe2b694d60>}),
#  'Mak': frozenset({<Reaction HEX7 at 0x7fbe2b8a07c0>}),
#  'BioH': frozenset({<Reaction PMEACPE at 0x7fbe2b08bac0>}),
#  'HisD': frozenset({<Reaction HISTD at 0x7fbe2b8bbee0>}),
#  'MltB': frozenset({<Reaction MLTGY1pp at 0x7fbe2b694ee0>,
#             <Reaction MLTGY2pp at 0x7fbe2b6a9820>,
#             <Reaction MLTGY3pp at 0x7fbe2b6a9880>,
#             <Reaction MLTGY4pp at 0x7fbe2b694d60>}),
#  'CoaA': frozenset({<Reaction PNTK at 0x7fbe2b0b7f40>}),
#  'Slt': frozenset({<Reaction MLTGY1pp at 0x7fbe2b694ee0>,
#             <Reaction MLTGY2pp at 0x7fbe2b6a9820>,
#             <Reaction MLTGY3pp at 0x7fbe2b6a9880>,
#             <Reaction MLTGY4pp at 0x7fbe2b694d60>}),
#  'MltA': frozenset({<Reaction MLTGY1pp at 0x7fbe2b694ee0>,
#             <Reaction MLTGY2pp at 0x7fbe2b6a9820>,
#             <Reaction MLTGY3pp at 0x7fbe2b6a9880>,
#             <Reaction MLTGY4pp at 0x7fbe2b694d60>}),
#  'PanF': frozenset({<Reaction PNTOt4pp at 0x7fbe2b04ce50>}),
#  'ScpB': frozenset({<Reaction MMCD at 0x7fbe2b6bdd90>}),
#  'HisB': frozenset({<Reaction HISTP at 0x7fbe2b8bb580>,
#             <Reaction IGPDH at 0x7fbe2b895ee0>}),
#  'RutC': frozenset({<Reaction POAACR at 0x7fbe2b076e50>}),
#  'HisS': frozenset({<Reaction HISTRS at 0x7fbe2b84ef10>}),
#  'ScpA': frozenset({<Reaction MMM2 at 0x7fbe2b04cf40>,
#             <Reaction MMM at 0x7fbe2b6bde20>}),
#  'MtlA': frozenset({<Reaction MNLptspp at 0x7fbe2b651be0>}),
#  'YdbK': frozenset({<Reaction POR5 at 0x7fbe2b076b80>}),
#  'UxuA': frozenset({<Reaction MNNH at 0x7fbe2b651a60>}),
#  'PoxB': frozenset({<Reaction POX at 0x7fbe2b00bd60>}),
#  'HisJ': frozenset({<Reaction HISabcpp at 0x7fbe2b8bb880>}),
#  'Ppx': frozenset({<Reaction PPA2 at 0x7fbe2b060f70>,
#             <Reaction PPA at 0x7fbe2b00bfd0>}),
#  'AroP': frozenset({<Reaction HISt2rpp at 0x7fbe2b8ffa00>,
#             <Reaction PHEt2rpp at 0x7fbe2b3e7df0>,
#             <Reaction TRPt2rpp at 0x7fbe2b138820>,
#             <Reaction TYRt2rpp at 0x7fbe2b183dc0>}),
#  'MoaD': frozenset({<Reaction MOADSUx at 0x7fbe2b666f10>,
#             <Reaction MPTS at 0x7fbe2b626a30>}),
#  'Ppa': frozenset({<Reaction PPA at 0x7fbe2b00bfd0>}),
#  'WaaA': frozenset({<Reaction MOAT2 at 0x7fbe2b67e9d0>,
#             <Reaction MOAT at 0x7fbe2b666d00>}),
#  'MhpC': frozenset({<Reaction HKNDDH at 0x7fbe2b8648b0>,
#             <Reaction HKNTDH at 0x7fbe2b864af0>}),
#  'HemC': frozenset({<Reaction HMBS at 0x7fbe2b864ee0>}),
#  'ThiD': frozenset({<Reaction HMPK1 at 0x7fbe2b8572e0>,
#             <Reaction PMPK at 0x7fbe2b0a3c70>}),
#  'PutP': frozenset({<Reaction PPAt4pp at 0x7fbe2b021f70>,
#             <Reaction PROt4pp at 0x7fbe2b391fa0>}),
#  'PdxK': frozenset({<Reaction HMPK1 at 0x7fbe2b8572e0>,
#             <Reaction PYDAMK at 0x7fbe2b2d3f70>,
#             <Reaction PYDXK at 0x7fbe2b2d3f10>,
#             <Reaction PYDXNK at 0x7fbe2b2d3cd0>}),
#  'RhtA': frozenset({<Reaction HOMt2pp at 0x7fbe2b86fd00>,
#             <Reaction THRt2pp at 0x7fbe2b194bb0>}),
#  'YbhA': frozenset({<Reaction MOBDabcpp at 0x7fbe2b67eeb0>,
#             <Reaction PDXPP at 0x7fbe2b421dc0>,
#             <Reaction PYDXPP at 0x7fbe2b2d3f40>,
#             <Reaction SULabcpp at 0x7fbe2b207b20>,
#             <Reaction TUNGSabcpp at 0x7fbe2b0cfc10>}),
#  'CysU': frozenset({<Reaction MOBDabcpp at 0x7fbe2b67eeb0>,
#             <Reaction SELtpp at 0x7fbe2b273d90>,
#             <Reaction SLNTtpp at 0x7fbe2b230fd0>,
#             <Reaction SULabcpp at 0x7fbe2b207b20>,
#             <Reaction TSULabcpp at 0x7fbe2b1243d0>}),
#  'CysA': frozenset({<Reaction MOBDabcpp at 0x7fbe2b67eeb0>,
#             <Reaction SELtpp at 0x7fbe2b273d90>,
#             <Reaction SLNTtpp at 0x7fbe2b230fd0>,
#             <Reaction SULabcpp at 0x7fbe2b207b20>,
#             <Reaction TSULabcpp at 0x7fbe2b1243d0>}),
#  'HemB': frozenset({<Reaction PPBNGS at 0x7fbe2b021d90>}),
#  'CysP': frozenset({<Reaction MOBDabcpp at 0x7fbe2b67eeb0>,
#             <Reaction SELtpp at 0x7fbe2b273d90>,
#             <Reaction SLNTtpp at 0x7fbe2b230fd0>,
#             <Reaction SULabcpp at 0x7fbe2b207b20>,
#             <Reaction TSULabcpp at 0x7fbe2b1243d0>}),
#  'RhtB': frozenset({<Reaction HOMt2pp at 0x7fbe2b86fd00>}),
#  'Ppc': frozenset({<Reaction PPC at 0x7fbe2b021fa0>}),
#  'MhpE': frozenset({<Reaction HOPNTAL at 0x7fbe2b864ca0>}),
#  'Dfp': frozenset({<Reaction PPCDC at 0x7fbe2b021ee0>,
#             <Reaction PPNCL2 at 0x7fbe2afcbb80>}),
#  'Pck': frozenset({<Reaction PPCK at 0x7fbe2b021e50>}),
#  'FolK': frozenset({<Reaction HPPK2 at 0x7fbe2b86ff10>}),
#  'Sbp': frozenset({<Reaction MOBDabcpp at 0x7fbe2b67eeb0>,
#             <Reaction SULabcpp at 0x7fbe2b207b20>,
#             <Reaction TSULabcpp at 0x7fbe2b1243d0>}),
#  'ScpC': frozenset({<Reaction PPCSCT at 0x7fbe2b036a90>}),
#  'CysW': frozenset({<Reaction MOBDabcpp at 0x7fbe2b67eeb0>,
#             <Reaction SELtpp at 0x7fbe2b273d90>,
#             <Reaction SLNTtpp at 0x7fbe2b230fd0>,
#             <Reaction SULabcpp at 0x7fbe2b207b20>,
#             <Reaction TSULabcpp at 0x7fbe2b1243d0>}),
#  'ModC': frozenset({<Reaction MOBDabcpp at 0x7fbe2b67eeb0>,
#             <Reaction SULabcpp at 0x7fbe2b207b20>,
#             <Reaction TUNGSabcpp at 0x7fbe2b0cfc10>}),
#  'ModA': frozenset({<Reaction MOBDabcpp at 0x7fbe2b67eeb0>,
#             <Reaction SULabcpp at 0x7fbe2b207b20>,
#             <Reaction TUNGSabcpp at 0x7fbe2b0cfc10>}),
#  'MocA': frozenset({<Reaction MOCDS at 0x7fbe2b666c70>}),
#  'Hyi': frozenset({<Reaction HPYRI at 0x7fbe2b878df0>}),
#  'ThrB': frozenset({<Reaction HSK at 0x7fbe2b810850>}),
#  'MetA': frozenset({<Reaction HSST at 0x7fbe2b810eb0>}),
#  'HisC': frozenset({<Reaction HSTPT at 0x7fbe2b81db50>}),
#  'Ppk': frozenset({<Reaction PPK2 at 0x7fbe2b036310>,
#             <Reaction PPK at 0x7fbe2b036e80>}),
#  'XdhA': frozenset({<Reaction HXAND at 0x7fbe2b81df70>,
#             <Reaction XAND at 0x7fbe2b10e070>}),
#  'DeoB': frozenset({<Reaction PPM2 at 0x7fbe2afcbdc0>,
#             <Reaction PPM at 0x7fbe2afcb910>}),
#  'XdhB': frozenset({<Reaction HXAND at 0x7fbe2b81df70>,
#             <Reaction XAND at 0x7fbe2b10e070>}),
#  'PanB': frozenset({<Reaction MOHMT at 0x7fbe2b67ee80>}),
#  'Mog': frozenset({<Reaction MPTAT at 0x7fbe2b612fd0>}),
#  'PbpC': frozenset({<Reaction MPTG2 at 0x7fbe2b6126a0>,
#             <Reaction MPTG at 0x7fbe2b612df0>}),
#  'YhfW': frozenset({<Reaction PPM at 0x7fbe2afcb910>}),
#  'MurJ': frozenset({<Reaction LIPIDIIFLIP at 0x7fbe2af7d730>,
#             <Reaction MPTG2 at 0x7fbe2b6126a0>,
#             <Reaction MPTG at 0x7fbe2b612df0>}),
#  'HemG': frozenset({<Reaction PPPGO3 at 0x7fbe2afcbf70>,
#             <Reaction PPPGO at 0x7fbe2afe0a00>}),
#  'MoaE': frozenset({<Reaction MPTS at 0x7fbe2b626a30>}),
#  'XdhC': frozenset({<Reaction HXAND at 0x7fbe2b81df70>,
#             <Reaction XAND at 0x7fbe2b10e070>}),
#  'HcaT': frozenset({<Reaction PPPNt2rpp at 0x7fbe2aff4850>}),
#  'HyaC': frozenset({<Reaction HYD1pp at 0x7fbe2b8c5f10>,
#             <Reaction HYD2pp at 0x7fbe2b937d90>,
#             <Reaction HYD3pp at 0x7fbe2b8cee20>}),
#  'PpsA': frozenset({<Reaction PPS at 0x7fbe2af88e20>}),
#  'HybO': frozenset({<Reaction HYD1pp at 0x7fbe2b8c5f10>,
#             <Reaction HYD2pp at 0x7fbe2b937d90>,
#             <Reaction HYD3pp at 0x7fbe2b8cee20>}),
#  'HyaB': frozenset({<Reaction HYD1pp at 0x7fbe2b8c5f10>,
#             <Reaction HYD2pp at 0x7fbe2b937d90>,
#             <Reaction HYD3pp at 0x7fbe2b8cee20>}),
#  'MoeB': frozenset({<Reaction MPTSS at 0x7fbe2b666af0>}),
#  'PhoA': frozenset({<Reaction PPTHpp at 0x7fbe2aff4a30>}),
#  'HyaA': frozenset({<Reaction HYD1pp at 0x7fbe2b8c5f10>,
#             <Reaction HYD2pp at 0x7fbe2b937d90>,
#             <Reaction HYD3pp at 0x7fbe2b8cee20>}),
#  'PurD': frozenset({<Reaction PRAGSr at 0x7fbe2b3d0f10>}),
#  'RutE': frozenset({<Reaction MSAR at 0x7fbe2b626850>}),
#  'PurM': frozenset({<Reaction PRAIS at 0x7fbe2b3e7fa0>}),
#  'FolD': frozenset({<Reaction MTHFC at 0x7fbe2b63bf10>,
#             <Reaction MTHFD at 0x7fbe2b63b940>}),
#  'HybA': frozenset({<Reaction HYD1pp at 0x7fbe2b8c5f10>,
#             <Reaction HYD2pp at 0x7fbe2b937d90>,
#             <Reaction HYD3pp at 0x7fbe2b8cee20>}),
#  'HisI': frozenset({<Reaction PRAMPC at 0x7fbe2b3e7f70>,
#             <Reaction PRATPP at 0x7fbe2b3fcee0>}),
#  ...}

# %%
one= pd.read_csv("one feasible value reactions anaerobic.csv")
flat= pd.read_csv("flat anaerobic.csv")
diff_saturated= pd.read_csv("diff_saturated anaerobic.csv")
Ushaped= pd.read_csv("Ushaped_reactions anaerobic.csv")
monotonically_increasingANDstable_reactions= pd.read_csv("monotonically increasing and stable reactions anaerobic.csv")
monotonically_increasing_only_reactions= pd.read_csv("monotonically increasing only reactions anaerobic.csv")
monotonically_decreasingANDstable_reactions= pd.read_csv("monotonically decreasing and stable reactions anaerobic.csv")
monotonically_decreasing_only_reactions= pd.read_csv("monotonically decreasing only reactions anaerobic.csv")
increasingANDdecreasingANDstable_reactions= pd.read_csv("increasing and decreasing and stable reactions anaerobic.csv")
increasingANDdecreasing_only_reactions= pd.read_csv("increasing and decreasing only reactions anaerobic.csv")

# %%
import csv

with open('dictionary.csv', 'w') as f:  
    writer = csv.writer(f)
    for k, v in dictionary.items():
       writer.writerow([k, v])

# %%
import pandas as pd
p= pd.read_csv('dictionary.csv', header= None)
p

headerList= ["Gene name", "Reaction"]
p.to_csv("dictionary_NEW.csv", header=headerList, index=False)
p2 = pd.read_csv("dictionary_NEW.csv")
print('\nModified file:')
print(p2)
# Out:
# Modified file:
#        Gene name                                           Reaction
# 0           PhoE  frozenset({<Reaction MALDtex at 0x7fbe2b707f40...
# 1           YlbA  frozenset({<Reaction UGCIAMH at 0x7fbe2aee5f40>})
# 2           OmpC  frozenset({<Reaction MALDtex at 0x7fbe2b707f40...
# 3           OmpF  frozenset({<Reaction MALDtex at 0x7fbe2b707f40...
# 4           OmpN  frozenset({<Reaction MALDtex at 0x7fbe2b707f40...
# ...          ...                                                ...
# 1339        YcjT      frozenset({<Reaction MPL at 0x7fbe2af25670>})
# 1340        YafJ     frozenset({<Reaction ASNO at 0x7fbe2af38700>})
# 1341        YgdH    frozenset({<Reaction PYRDC at 0x7fbe2af38f40>})
# 1342  Locus 3025  frozenset({<Reaction HPA3MOFAD at 0x7fbe2aecfb...
# 1343        YcjM     frozenset({<Reaction SUCP at 0x7fbe2aee5790>})
#
# [1344 rows x 2 columns]

# %%
boolean_findings = p2['Reaction'].str.contains('UGCIAMH')

boolean_findings

i=0
gene_names= list()
while i <1343:
    if boolean_findings[i] ==True:
        
        l= p2.iloc[i, 0]
        gene_names.append(l)
    i=i+1
gene_names
# Out:
# ['YlbA']

# %%
diff_saturated["Reaction names"]
# Out:
# 0          EX_ppt_e
# 1          EX_fe2_e
# 2     ACOLIPAabctex
# 3               ADA
# 4               ADD
#           ...
# 87              POX
# 88              PPK
# 89              PPM
# 90    L_LACD2_copy2
# 91      XTSNH_copy2
# Name: Reaction names, Length: 92, dtype: object

# %%
z=0
saturated_gene_names= list()
l= str()

while z< len(diff_saturated):

    boolean_findings = p2['Reaction'].str.contains(diff_saturated["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            saturated_gene_names.append(l)
        i=i+1
    
    z=z+1

saturated_gene_names
# Out:
# ['LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'DdpX',
#  'DdpA',
#  'DdpB',
#  'DdpD',
#  'DdpC',
#  'DppF',
#  'DdpF',
#  'DppB',
#  'DppD',
#  'DppA',
#  'DppC',
#  'LivJ',
#  'LivM',
#  'LivF',
#  'LivH',
#  'LivG',
#  'PuuC',
#  'GltJ',
#  'GltK',
#  'GltI',
#  'GltL',
#  'YehX',
#  'YehW',
#  'YehY',
#  'OsmF',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'CarA',
#  'CarB',
#  'ZntA',
#  'ZntA',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'ProX',
#  'ProV',
#  'ProW',
#  'ProX',
#  'ProV',
#  'ProW',
#  'ProX',
#  'ProV',
#  'ProW',
#  'CydD',
#  'CydC',
#  'AraG',
#  'AraF',
#  'AraH',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'ArtM',
#  'ArtJ',
#  'HisP',
#  'HisM',
#  'HisQ',
#  'ArgT',
#  'ArtP',
#  'ArtI',
#  'ArtQ',
#  'FeoB',
#  'GlpA',
#  'GlpD',
#  'GlpB',
#  'GlpC',
#  'GlpA',
#  'GlpB',
#  'GlpC',
#  'GlpA',
#  'GlpB',
#  'GlpC',
#  'NadB',
#  'NadB',
#  'NadB',
#  'MglC',
#  'MglA',
#  'MglB',
#  'AspA',
#  'AspC',
#  'AspS',
#  'YtfR',
#  'YtfT',
#  'MglC',
#  'MglA',
#  'YjfF',
#  'YtfQ',
#  'MglB',
#  'GltJ',
#  'GltK',
#  'GltI',
#  'GltL',
#  'YehX',
#  'YehW',
#  'YehY',
#  'OsmF',
#  'UgpA',
#  'UgpB',
#  'UgpE',
#  'UgpC',
#  'IdnD',
#  'ZntA',
#  'LivJ',
#  'LivM',
#  'LivF',
#  'LivH',
#  'LivG',
#  'HisP',
#  'HisM',
#  'HisQ',
#  'HisJ',
#  'GhrB',
#  'GhrA',
#  'Dld',
#  'LivJ',
#  'LivM',
#  'LivF',
#  'LivH',
#  'LivG',
#  'LivK',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'HisP',
#  'HisM',
#  'HisQ',
#  'ArgT',
#  'Mqo',
#  'Mqo',
#  'MgtA',
#  'Ndh',
#  'Ndh',
#  'Ndh',
#  'MdaB',
#  'MdaB',
#  'MdaB',
#  'PntA',
#  'PntB',
#  'SthA',
#  'ZntA',
#  'HscC',
#  'RsgA',
#  'YjjX',
#  'RsgA',
#  'YjjX',
#  'RsgA',
#  'AppA',
#  'RsgA',
#  'MutT',
#  'MazG',
#  'RdgB',
#  'MutT',
#  'MazG',
#  'NudI',
#  'MazG',
#  'NudG',
#  'MazG',
#  'NudG',
#  'NudB',
#  'MazG',
#  'MazG',
#  'NudI',
#  'MazG',
#  'MazG',
#  'HisP',
#  'HisM',
#  'HisQ',
#  'ArgT',
#  'Lpd',
#  'FldB',
#  'FldA',
#  'Zwf',
#  'AceF',
#  'AceE',
#  'IspG',
#  'HisB',
#  'ProX',
#  'ProV',
#  'ProW',
#  'PotD',
#  'PotB',
#  'PotF',
#  'YdcS',
#  'YdcV',
#  'PotA',
#  'PotI',
#  'PotH',
#  'PotG',
#  'PotC',
#  'YdcU',
#  'YdcT',
#  'SodA',
#  'SodB',
#  'SodC',
#  'GlyA',
#  'LtaE',
#  'LivJ',
#  'LivM',
#  'LivF',
#  'LivH',
#  'LivG',
#  'LivJ',
#  'LivM',
#  'LivF',
#  'LivH',
#  'LivG',
#  'XylH',
#  'XylG',
#  'XylF',
#  'ZntA',
#  'PoxB',
#  'SolA',
#  'Ppx',
#  'SurE',
#  'AraG',
#  'AraF',
#  'AraH',
#  'PreB',
#  'PreA',
#  'YgdH']

# %%
z=0
one_gene_names= list()
l= str()

while z< len(one):

    boolean_findings = p2['Reaction'].str.contains(one['1 feasible value'][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            one_gene_names.append(l)
        i=i+1
    
    z=z+1

one_gene_names
# Out:
# ['LamB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CpdB',
#  'CpdB',
#  'CpdB',
#  'CpdB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'Aas',
#  'Aas',
#  'Aas',
#  'Aas',
#  'Aas',
#  'Aas',
#  'Aas',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'Aas',
#  'Aas',
#  'Aas',
#  'Aas',
#  'Aas',
#  'Aas',
#  'Aas',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FabA',
#  'FabZ',
#  'RutD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'MhpA',
#  'RffT',
#  'MalS',
#  'MhpA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'LyxK',
#  'BglA',
#  'GabT',
#  'PuuE',
#  'Prr',
#  'CpdB',
#  'CpdB',
#  'CpdB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CpdB',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'AtoE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FabG',
#  'FabG',
#  'FabB',
#  'FabF',
#  'FabB',
#  'FabF',
#  'FabB',
#  'FabB',
#  'FabF',
#  'FabB',
#  'FabB',
#  'FabF',
#  'NhoA',
#  'CobU',
#  'FabB',
#  'FabB',
#  'FabF',
#  'FabF',
#  'FabB',
#  'FabF',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NagK',
#  'Rfe',
#  'FabB',
#  'FabF',
#  'OppF',
#  'MppA',
#  'OppB',
#  'OppC',
#  'OppD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'TynA',
#  'PtsH',
#  'NagE',
#  'Crr',
#  'PtsG',
#  'PtsI',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ThrC',
#  'LdcA',
#  'ArgB',
#  'ArgA',
#  'IlvN',
#  'IlvI',
#  'IlvH',
#  'IlvB',
#  'OppF',
#  'OppB',
#  'OppC',
#  'OppD',
#  'OppA',
#  'MurQ',
#  'RffM',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'IdnO',
#  'IdnT',
#  'PtsH',
#  'PtsI',
#  'ManY',
#  'ManZ',
#  'ManX',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PtsH',
#  'Crr',
#  'PtsI',
#  'MurP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NanT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Mtn',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GutQ',
#  'KdsD',
#  'OmpC',
#  'OmpF',
#  'Deleted',
#  'NanA',
#  'FadE',
#  'FadE',
#  'FadE',
#  'FadE',
#  'FadE',
#  'ArgE',
#  'FadE',
#  'FadE',
#  'FadE',
#  'S0001',
#  'Tam',
#  'AcnA',
#  'AcnB',
#  'AcnA',
#  'AcnB',
#  'AstC',
#  'ArgD',
#  'PlsC',
#  'ArgC',
#  'CusA',
#  'CusF',
#  'CusC',
#  'CusB',
#  'Mtn',
#  'PurH',
#  'PurK',
#  'PurE',
#  'KgtP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Aas',
#  'AcpP',
#  'AcpT',
#  'AcpS',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'EamA',
#  'EamB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PabC',
#  'PabA',
#  'PabB',
#  'YcjG',
#  'AlaS',
#  'XanP',
#  'PurP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'SpeD',
#  'FrmA',
#  'NupC',
#  'NupG',
#  'Tsx',
#  'CobU',
#  'CobS',
#  'BtuD',
#  'BtuF',
#  'BtuC',
#  'ExbD',
#  'ExbB',
#  'BtuB',
#  'TonB',
#  'NudF',
#  'NudE',
#  'AlsK',
#  'RpiB',
#  'AllC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AllB',
#  'YbbW',
#  'YbbW',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AlsE',
#  'CysC',
#  'PurB',
#  'PurB',
#  'AlsC',
#  'AlsB',
#  'AlsA',
#  'PurA',
#  'LpxB',
#  'NagA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Lpp',
#  'Lnt',
#  'Lpp',
#  'Lnt',
#  'AmpD',
#  'AmiC',
#  'AmiB',
#  'AmiA',
#  'TrpD',
#  'TrpE',
#  'GlpE',
#  'PspE',
#  'AmiC',
#  'AmiB',
#  'AmiA',
#  'NagZ',
#  'AmpG',
#  'AmpD',
#  'AmiC',
#  'AmiB',
#  'AmiA',
#  'AmiC',
#  'AmiB',
#  'AmiA',
#  'LdcA',
#  'UxaA',
#  'AmpD',
#  'AmpD',
#  'LdcA',
#  'MalQ',
#  'NanE',
#  'NanK',
#  'NagZ',
#  'AmpG',
#  'NagZ',
#  'RfaD',
#  'RfaD',
#  'SpeB',
#  'AmpG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'BioA',
#  'UbiE',
#  'ThiC',
#  'PlsC',
#  'PlsC',
#  'S0001',
#  'PlsC',
#  'PepB',
#  'PepA',
#  'PepN',
#  'PepD',
#  'PepB',
#  'PepA',
#  'PepN',
#  'PepD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'PlsC',
#  'BioF',
#  'PlsC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AnmK',
#  'TrpD',
#  'PlsC',
#  'ApaH',
#  'AspS',
#  'SpeE',
#  'PlsY',
#  'PlsY',
#  'PlsY',
#  'ArsC',
#  'GrxB',
#  'PlsY',
#  'QueF',
#  'AstA',
#  'PlsY',
#  'S0001',
#  'IspE',
#  'Cfa',
#  'Cfa',
#  'Cfa',
#  'HisG',
#  'PlsY',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Cfa',
#  'DppF',
#  'DppB',
#  'DppD',
#  'DppA',
#  'DppC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MoeA',
#  'MobB',
#  'MobA',
#  'MobB',
#  'MobA',
#  'CysQ',
#  'BetA',
#  'PheA',
#  'TyrA',
#  'PlsY',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'BioB',
#  'AroC',
#  'MenF',
#  'EntC',
#  'UbiC',
#  'PtsI',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'TauB',
#  'TauC',
#  'TauA',
#  'SsuA',
#  'SsuC',
#  'SsuB',
#  'HcaF',
#  'HcaD',
#  'HcaE',
#  'HcaC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AtoE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MobB',
#  'MobA',
#  'MobB',
#  'MobA',
#  'MoeA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CadB',
#  'YbhO',
#  'Cls',
#  'BtuR',
#  'ExbD',
#  'ExbB',
#  'BtuB',
#  'TonB',
#  'BtuD',
#  'BtuF',
#  'BtuC',
#  'YbhO',
#  'Cls',
#  'YbhO',
#  'Cls',
#  'YbhO',
#  'Cls',
#  'BtuD',
#  'BtuF',
#  'BtuC',
#  'ExbD',
#  'ExbB',
#  'BtuB',
#  'TonB',
#  'YbhO',
#  'Cls',
#  'YbhO',
#  'Cls',
#  'YbhO',
#  'Cls',
#  'BtuR',
#  'S0001',
#  'ClcB',
#  'ClcA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'QueC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GldA',
#  'LpxT',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'MsbA',
#  'RibD',
#  'MoaC',
#  'MoaA',
#  'HemF',
#  'HemN',
#  'HemN',
#  'CaiB',
#  'CaiD',
#  'CaiB',
#  'AraA',
#  'CaiD',
#  'CaiC',
#  'QueD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CaiT',
#  'NupC',
#  'NupG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Tsx',
#  'CodA',
#  'CodB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'YgeX',
#  'LysA',
#  'DapF',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PyrG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'RibB',
#  'BioD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GlpE',
#  'PspE',
#  'PspE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CynS',
#  'CynX',
#  'ChbF',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FadL',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Cdd',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MetC',
#  'TnaA',
#  'IscS',
#  'SufS',
#  'SufE',
#  'NupC',
#  'NupG',
#  'Tsx',
#  'FadL',
#  'DgoK',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CysM',
#  'CysK',
#  'CsdA',
#  'SelA',
#  'CsdA',
#  'KdgT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'KdgK',
#  'MetC',
#  'MalY',
#  'CysS',
#  'AroG',
#  'AroF',
#  'AroH',
#  'DgoA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NupG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'IlvD',
#  'PtsH',
#  'PtsI',
#  'AscF',
#  'BglF',
#  'NupC',
#  'NupG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'EntA',
#  'HcaB',
#  'MhpB',
#  'MhpB',
#  'DapB',
#  'AroD',
#  'DapA',
#  'FolA',
#  'FolM',
#  'FolC',
#  'FolM',
#  'MenA',
#  'MenB',
#  'YbgC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NupG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DkgB',
#  'DkgA',
#  'FolB',
#  'PyrC',
#  'IspA',
#  'RibD',
#  'HcaB',
#  'UbiG',
#  'RibD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FolP',
#  'S0001',
#  'NfsB',
#  'AdiC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NudB',
#  'MutT',
#  'NfsB',
#  'FolX',
#  'AroB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CoaE',
#  'NudF',
#  'NudE',
#  'IlvC',
#  'PanE',
#  'DapB',
#  'NadC',
#  'WzyE',
#  'WzzE',
#  'DsbB',
#  'DsbA',
#  'WzyE',
#  'WzzE',
#  'WzyE',
#  'WzzE',
#  'WzxE',
#  'DsbC',
#  'TrxA',
#  'TrxC',
#  'DsbD',
#  'CycA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FumB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'ArgH',
#  'FadJ',
#  'FadB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ArgG',
#  'NupC',
#  'NupG',
#  'Tsx',
#  'LpxL',
#  'LpxM',
#  'LpxP',
#  'LpxM',
#  'FabI',
#  'ArgS',
#  'Dxr',
#  'Dxs',
#  'XylB',
#  'Epd',
#  'GapA',
#  'EntD',
#  'FabI',
#  'EutB',
#  'EutC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'SsuA',
#  'SsuC',
#  'SsuB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UhpT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Asd',
#  'TesB',
#  'TesB',
#  'UlaG',
#  'TesB',
#  'TesB',
#  'TesB',
#  'FadK',
#  'FadD',
#  'TesB',
#  'PtsH',
#  'PtsI',
#  'UlaC',
#  'UlaB',
#  'UlaA',
#  'TesB',
#  'TesB',
#  'FrmA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'TesB',
#  'S0001',
#  'FadK',
#  'FadD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FadK',
#  'FadD',
#  'FadK',
#  'FadD',
#  'S0001',
#  'FucI',
#  'FucK',
#  'FucA',
#  'YgbL',
#  'FadK',
#  'FadD',
#  'FadK',
#  'FadD',
#  'FadK',
#  'FadD',
#  'FadK',
#  'FadD',
#  'FadK',
#  'FadD',
#  'HemH',
#  'SsuD',
#  'SsuD',
#  'SsuD',
#  'SsuD',
#  'SsuD',
#  'S0001',
#  'S0001',
#  'YtfE',
#  'Fmt',
#  'FecB',
#  'FecD',
#  'FecC',
#  'FecE',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FecA',
#  'FepG',
#  'FepC',
#  'FepD',
#  'FepB',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'CirA',
#  'Fiu',
#  'RibF',
#  'AsnS',
#  'Frc',
#  'Fre',
#  'FruK',
#  'FrlB',
#  'FrlC',
#  'FrlD',
#  'FrlA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GntP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PtsH',
#  'PtsI',
#  'FruB',
#  'FruA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FhuF',
#  'ArsB',
#  'FhuF',
#  'GlmU',
#  'Agp',
#  'RffH',
#  'RfbA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  ...]

# %%
z=0
flat_gene_names= list()
l= str()

while z< len(flat):

    boolean_findings = p2['Reaction'].str.contains(flat["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            flat_gene_names.append(l)
        i=i+1
    
    z=z+1

flat_gene_names
# Out:
# ['GhrB',
#  'GhrB',
#  'GhrB',
#  'GabP',
#  'FadA',
#  'AtoB',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'Acs',
#  'Deleted',
#  'PurT',
#  'AckA',
#  'IlvN',
#  'IlvI',
#  'IlvH',
#  'IlvB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Acs',
#  'EamA',
#  'EamB',
#  'GlcA',
#  'LldP',
#  'ActP',
#  'Add',
#  'LpxC',
#  'RffT',
#  'Ade',
#  'LigA',
#  'NudC',
#  'GlyA',
#  'LtaE',
#  'GlyA',
#  'LtaE',
#  'AlaA',
#  'AlaC',
#  'GlyA',
#  'LtaE',
#  'CycA',
#  'YaaJ',
#  'Adk',
#  'Adk',
#  'FeaB',
#  'Adk',
#  'RihC',
#  'Apt',
#  'MalQ',
#  'MalQ',
#  'MalQ',
#  'Amn',
#  'GltP',
#  'BetB',
#  'BisC',
#  'ChaA',
#  'YrbG',
#  'CaiC',
#  'ProP',
#  'ProP',
#  'CaiT',
#  'Add',
#  'CaiC',
#  'FadB',
#  'FadB',
#  'FadB',
#  'IlvD',
#  'PtsH',
#  'PtsI',
#  'DhaK',
#  'DhaL',
#  'DhaM',
#  'DadA',
#  'FolB',
#  'PyrD',
#  'GhrB',
#  'GhrB',
#  'IspH',
#  'FabI',
#  'FabI',
#  'FabI',
#  'DsbB',
#  'DsbA',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'YbiV',
#  'FabI',
#  'FabI',
#  'AcpH',
#  'AcpH',
#  'AcpH',
#  'AcpH',
#  'AcpH',
#  'FabI',
#  'CysI',
#  'CysJ',
#  'FdnI',
#  'FdnG',
#  'FdoI',
#  'FdnH',
#  'FdoG',
#  'FdoH',
#  'IaaA',
#  'AnsA',
#  'AnsB',
#  'FadK',
#  'FadD',
#  'AnsB',
#  'AsnB',
#  'Fre',
#  'CysI',
#  'CysJ',
#  'Fre',
#  'CysI',
#  'CysJ',
#  'SsuE',
#  'Fau',
#  'GlgB',
#  'YbiV',
#  'GlgP',
#  'MalP',
#  'GlgP',
#  'MalP',
#  'GlgA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'LamB',
#  'GlgX',
#  'GlgC',
#  'GadC',
#  'PabB',
#  'AnsB',
#  'YbaS',
#  'YneH',
#  'PurT',
#  'NudK',
#  'GltD',
#  'GltB',
#  'GltP',
#  'GltS',
#  'GlxK',
#  'GarK',
#  'GarK',
#  'GhrB',
#  'GhrA',
#  'GlcA',
#  'LldP',
#  'AtoA',
#  'AtoD',
#  'ActP',
#  'FadJ',
#  'FadB',
#  'Gpt',
#  'Hpt',
#  'HycC',
#  'HycG',
#  'HycE',
#  'HycD',
#  'HycF',
#  'HycB',
#  'HyaC',
#  'HybO',
#  'HyaB',
#  'HyaA',
#  'HybA',
#  'HybB',
#  'HybC',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'GlcD',
#  'GlcF',
#  'GlcE',
#  'MenF',
#  'EntC',
#  'Glk',
#  'Mak',
#  'TolC',
#  'AcrF',
#  'AcrE',
#  'Mtr',
#  'RihC',
#  'Gsk',
#  'IspH',
#  'Hyi',
#  'GhrB',
#  'GhrA',
#  'IlvC',
#  'FabB',
#  'FabF',
#  'FabH',
#  'CycA',
#  'YeaV',
#  'LldD',
#  'YkgF',
#  'YkgE',
#  'YkgG',
#  'LldD',
#  'YkgF',
#  'YkgE',
#  'YkgG',
#  'YaaJ',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DacC',
#  'DacB',
#  'DacD',
#  'DacA',
#  'MaeA',
#  'FldB',
#  'FldA',
#  'IspG',
#  'MalZ',
#  'MalZ',
#  'MalZ',
#  'ScpA',
#  'YbiV',
#  'AcnB',
#  'NuoC',
#  'NuoE',
#  'NuoM',
#  'NuoH',
#  'NuoF',
#  'NuoB',
#  'NuoA',
#  'NuoL',
#  'NuoG',
#  'NuoK',
#  'NuoJ',
#  'NuoN',
#  'NuoI',
#  'Gsk',
#  'NarH',
#  'NarG',
#  'NarY',
#  'NarW',
#  'NarZ',
#  'NarV',
#  'NarI',
#  'NarJ',
#  'ChaA',
#  'MdfA',
#  'Adk',
#  'Ndk',
#  'Hmp',
#  'NorV',
#  'NorW',
#  'CpdB',
#  'AphA',
#  'SurE',
#  'UshA',
#  'AphA',
#  'YfbR',
#  'SurE',
#  'UshA',
#  'CpdB',
#  'AphA',
#  'SurE',
#  'UshA',
#  'LplA',
#  'Dgt',
#  'Dgt',
#  'Gpp',
#  'NrfC',
#  'NrfD',
#  'NrfA',
#  'NrfB',
#  'Eda',
#  'PfkA',
#  'PfkB',
#  'PfkA',
#  'Gpt',
#  'Hpt',
#  'PdxH',
#  'ProP',
#  'PutP',
#  'Prs',
#  'YgiN',
#  'PhnN',
#  'YbiV',
#  'AphA',
#  'Pta',
#  'EutD',
#  'Sad',
#  'SucD',
#  'SucC',
#  'DsdA',
#  'TnaA',
#  'SdaA',
#  'TdcG',
#  'SdaB',
#  'Deleted',
#  'SdaC',
#  'SstT',
#  'GlyA',
#  'GlyA',
#  'LtaE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Deleted',
#  'YdfG',
#  'CydD',
#  'CydC',
#  'Ggt',
#  'GsiA',
#  'GsiB',
#  'GsiC',
#  'GsiD',
#  'Tdh',
#  'IlvA',
#  'TrpA',
#  'TrpB',
#  'TrpA',
#  'TrpB',
#  'GlxR',
#  'GarR',
#  'Upp',
#  'UraA',
#  'RutG',
#  'AvtA',
#  'RihC',
#  'RihA',
#  'RihB',
#  'Udk',
#  'IlvE',
#  'RihC',
#  'LldD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AcnB',
#  'ScpA',
#  'MenB',
#  'FadB',
#  'FadB',
#  'AvtA',
#  'PutP',
#  'ScpC',
#  'FolK',
#  'Ppk',
#  'DeoB',
#  'YhfW',
#  'LeuC',
#  'LeuD',
#  'GhrB',
#  'FeaB',
#  'FolB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'AraE',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'YdeA',
#  'FadJ',
#  'FadB',
#  'FadB',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'LldD',
#  'YiaK',
#  'RihC',
#  'RihA',
#  'RihB']

# %%
z=0
Ushaped_gene_names= list()
l= str()

while z< len(Ushaped):

    boolean_findings = p2['Reaction'].str.contains(Ushaped["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            Ushaped_gene_names.append(l)
        i=i+1
    
    z=z+1

Ushaped_gene_names
# Out:
# ['CueO',
#  'CopA',
#  'Deleted',
#  'KdpB',
#  'KdpC',
#  'KdpA',
#  'MgtA',
#  'NikC',
#  'NikE',
#  'NikD',
#  'NikB',
#  'NikA',
#  'PstA',
#  'PstB',
#  'PstS',
#  'PstC',
#  'YbhA',
#  'CysU',
#  'CysA',
#  'CysP',
#  'Sbp',
#  'CysW',
#  'ModC',
#  'ModA',
#  'ZnuC',
#  'ZnuA',
#  'ZnuB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AcpP',
#  'PlsX',
#  'NudB',
#  'MutT',
#  'Cdh',
#  'GmhB',
#  'Ppx',
#  'Ppa',
#  'PutP',
#  'SurE',
#  'HemF',
#  'HemN',
#  'HemG']

# %%
z=0
monotonically_increasingANDstable_reactions_gene_names= list()
l= str()

while z< len(monotonically_increasingANDstable_reactions):

    boolean_findings = p2['Reaction'].str.contains(monotonically_increasingANDstable_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            monotonically_increasingANDstable_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

monotonically_increasingANDstable_reactions_gene_names
# Out:
# ['PtsH', 'PtsI', 'ManY', 'ManZ', 'ManX', 'TalB', 'TalA']

# %%
z=0
monotonically_increasing_only_reactions_gene_names= list()
l= str()

while z< len(monotonically_increasing_only_reactions):

    boolean_findings = p2['Reaction'].str.contains(monotonically_increasing_only_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            monotonically_increasing_only_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

monotonically_increasing_only_reactions_gene_names
# Out:
# ['PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GhrB',
#  'AtoA',
#  'AtoD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'AcpP',
#  'FabH',
#  'DdpA',
#  'DdpB',
#  'DdpD',
#  'DdpC',
#  'DppF',
#  'DdpF',
#  'DppB',
#  'DppD',
#  'DppA',
#  'DppC',
#  'Adk',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AldB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'YdfG',
#  'CycA',
#  'BetT',
#  'YeaV',
#  'BetB',
#  'BisC',
#  'AtoA',
#  'AtoD',
#  'YahI',
#  'YbcF',
#  'YqeA',
#  'CycA',
#  'ProP',
#  'CusA',
#  'CusF',
#  'CusC',
#  'CusB',
#  'Dcd',
#  'CyoC',
#  'CyoB',
#  'CyoD',
#  'CyoA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'RihC',
#  'NupC',
#  'NupG',
#  'Cdd',
#  'RihA',
#  'RihB',
#  'Udk',
#  'RihC',
#  'RihA',
#  'RihB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GlcA',
#  'LldP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PyrD',
#  'DmsA',
#  'YnfH',
#  'DmsB',
#  'YnfE',
#  'YnfF',
#  'DmsC',
#  'YnfG',
#  'TorY',
#  'TorZ',
#  'TorY',
#  'TorZ',
#  'DmsA',
#  'DmsB',
#  'DmsC',
#  'TorY',
#  'TorZ',
#  'TorY',
#  'TorZ',
#  'YiaK',
#  'AdiA',
#  'SpeA',
#  'FabI',
#  'FabI',
#  'YdfG',
#  'Eno',
#  'FabI',
#  'FabI',
#  'Fes',
#  'Fes',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Fre',
#  'Fre',
#  'CysI',
#  'CysJ',
#  'SsuE',
#  'AnsP',
#  'DctA',
#  'FhuF',
#  'AphA',
#  'S0001',
#  'NadB',
#  'PtsH',
#  'Crr',
#  'PtsG',
#  'PtsI',
#  'ManY',
#  'ManZ',
#  'ManX',
#  'MalX',
#  'GlnQ',
#  'GlnP',
#  'GlnH',
#  'GalP',
#  'PurN',
#  'AnsB',
#  'YeaV',
#  'ProP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GhrB',
#  'ActP',
#  'Lpd',
#  'GlcA',
#  'LldP',
#  'GcvP',
#  'GcvT',
#  'GcvH',
#  'GhrA',
#  'GlpT',
#  'IdnD',
#  'AtoE',
#  'FieF',
#  'BrnQ',
#  'GuaB',
#  'AroP',
#  'XdhA',
#  'XdhB',
#  'XdhC',
#  'LacZ',
#  'BglX',
#  'BrnQ',
#  'LipB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MalP',
#  'MalP',
#  'MalP',
#  'NadE',
#  'Hmp',
#  'NadD',
#  'UbiF',
#  'UbiH',
#  'UbiB',
#  'ProC',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'PgpB',
#  'GuaD',
#  'PgpB',
#  'PgpB',
#  'PgpB',
#  'PgpB',
#  'PgpB',
#  'PgpB',
#  'Pgk',
#  'GrxB',
#  'TrxA',
#  'TrxC',
#  'CysH',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'GrxB',
#  'CysH',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'YqaB',
#  'Pgm',
#  'PitA',
#  'PitB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AraB',
#  'PotE',
#  'GrxB',
#  'TrxA',
#  'TrxC',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdA',
#  'NrdB',
#  'NrdF',
#  'NrdE',
#  'GrxB',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdF',
#  'NrdE',
#  'GrxB',
#  'TrxA',
#  'TrxC',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdA',
#  'NrdB',
#  'NrdF',
#  'NrdE',
#  'GrxB',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdF',
#  'NrdE',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'RpiB',
#  'RpiA',
#  'Sad',
#  'GabD',
#  'SdhD',
#  'SdhA',
#  'SdhB',
#  'SdhC',
#  'DcuA',
#  'DcuB',
#  'DcuC',
#  'DcuB',
#  'FumB',
#  'DmlA',
#  'TtdA',
#  'TtdB',
#  'YchM',
#  'DmsA',
#  'YnfH',
#  'DmsB',
#  'YnfE',
#  'YnfF',
#  'DmsC',
#  'YnfG',
#  'TorY',
#  'TorZ',
#  'TorC',
#  'TorA',
#  'TorY',
#  'TorZ',
#  'TorC',
#  'TorA',
#  'DmsA',
#  'DmsB',
#  'DmsC',
#  'TorY',
#  'TorZ',
#  'TorC',
#  'TorA',
#  'TorY',
#  'TorZ',
#  'TorC',
#  'TorA',
#  'PtsH',
#  'Crr',
#  'PtsI',
#  'TreB',
#  'TrpA',
#  'TrpB',
#  'Mpl',
#  'CpsG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'BrnQ',
#  'YgaH',
#  'YgaZ',
#  'IspG',
#  'XylE',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'GhrB']

# %%
z=0
monotonically_decreasingANDstable_reactions_gene_names= list()
l= str()

while z< len(monotonically_decreasingANDstable_reactions):

    boolean_findings = p2['Reaction'].str.contains(monotonically_decreasingANDstable_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            monotonically_decreasingANDstable_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

monotonically_decreasingANDstable_reactions_gene_names
# Out:
# ['AldB',
#  'DctA',
#  'DcuA',
#  'DcuB',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'AppC',
#  'AppB',
#  'AppC',
#  'AppB',
#  'CydB',
#  'CydA',
#  'YdeA',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'FbaA',
#  'MntH',
#  'DcuA',
#  'DcuB',
#  'DcuC',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'XanP',
#  'YdeA',
#  'SetB',
#  'SetA',
#  'DcuA',
#  'DcuB',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'CorA',
#  'NhaB',
#  'NhaA',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'BtuE',
#  'NapA',
#  'NapC',
#  'NapB',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'DcuA',
#  'DcuB',
#  'TrxA',
#  'TrxC',
#  'BtuE',
#  'Bcp',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'XanP',
#  'XanQ']

# %%
z=0
monotonically_decreasing_only_reactions_gene_names= list()
l= str()

while z< len(monotonically_decreasing_only_reactions):

    boolean_findings = p2['Reaction'].str.contains(monotonically_decreasing_only_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            monotonically_decreasing_only_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

monotonically_decreasing_only_reactions_gene_names
# Out:
# ['NudJ',
#  'Cof',
#  'Aas',
#  'AcpP',
#  'Aas',
#  'AcpP',
#  'Aas',
#  'AcpP',
#  'Aas',
#  'AcpP',
#  'Aas',
#  'AcpP',
#  'Aas',
#  'AcpP',
#  'Aas',
#  'AcpP',
#  'Aas',
#  'AcpP',
#  'Aas',
#  'AcpP',
#  'AcpP',
#  'PlsX',
#  'AcpP',
#  'PlsX',
#  'AcpP',
#  'PlsX',
#  'AcpP',
#  'PlsX',
#  'AcpP',
#  'PlsX',
#  'CyaA',
#  'DkgB',
#  'DkgA',
#  'Gpr',
#  'YeaE',
#  'GldA',
#  'ApaH',
#  'LysU',
#  'Cdh',
#  'YccX',
#  'YccX',
#  'YccX',
#  'YccX',
#  'YccX',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'YccX',
#  'ZupT',
#  'Cdh',
#  'YccX',
#  'Cdh',
#  'Cdh',
#  'Cdh',
#  'Cdh',
#  'Cdh',
#  'FhuB',
#  'FhuC',
#  'FhuD',
#  'S0001',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FhuE',
#  'CdsA',
#  'FhuB',
#  'FhuC',
#  'FhuD',
#  'CdsA',
#  'CdsA',
#  'ZntA',
#  'S0001',
#  'CdsA',
#  'CdsA',
#  'EntE',
#  'Cmk',
#  'Cmk',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DeoC',
#  'YdgI',
#  'Eda',
#  'RhmA',
#  'Edd',
#  'PreB',
#  'PreA',
#  'DeoD',
#  'DeoA',
#  'NudI',
#  'Dut',
#  'ArgO',
#  'AcpH',
#  'AcpH',
#  'TesB',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FhuA',
#  'FieF',
#  'FhuB',
#  'FhuC',
#  'FhuD',
#  'S0001',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FhuA',
#  'FrdC',
#  'FrdB',
#  'FrdD',
#  'FrdA',
#  'FrdC',
#  'FrdB',
#  'FrdD',
#  'FrdA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FhuB',
#  'FhuC',
#  'FhuD',
#  'S0001',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FhuA',
#  'PurU',
#  'FepG',
#  'FepC',
#  'FepD',
#  'FepB',
#  'S0001',
#  'TolC',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FepA',
#  'EntS',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FhuB',
#  'FhuC',
#  'FhuD',
#  'S0001',
#  'GpsA',
#  'YbiV',
#  'ProA',
#  'NagB',
#  'Zwf',
#  'GalU',
#  'GapA',
#  'ProB',
#  'Kbl',
#  'GloB',
#  'ChaA',
#  'KefC',
#  'KefB',
#  'MdfA',
#  'FucO',
#  'LacY',
#  'S0001',
#  'GloA',
#  'YdfG',
#  'ArgO',
#  'PrpD',
#  'PrpB',
#  'PrpC',
#  'CpsB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MelB',
#  'YdeA',
#  'ScpB',
#  'ZitB',
#  'FieF',
#  'MgsA',
#  'LigA',
#  'NudC',
#  'GrxB',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'FolD',
#  'FolD',
#  'Gss',
#  'Gss',
#  'Adk',
#  'Ndk',
#  'S0001',
#  'Adk',
#  'Ndk',
#  'AphA',
#  'YfbR',
#  'SurE',
#  'YjjG',
#  'UshA',
#  'AphA',
#  'SurE',
#  'UshA',
#  'Gor',
#  'CpdB',
#  'AphA',
#  'SurE',
#  'UshA',
#  'AphA',
#  'YfbR',
#  'SurE',
#  'YjjG',
#  'UshA',
#  'AphA',
#  'YfbR',
#  'SurE',
#  'UshA',
#  'CydD',
#  'CydC',
#  'GsiA',
#  'GsiB',
#  'GsiC',
#  'GsiD',
#  'RelA',
#  'PutA',
#  'SerA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Pgl',
#  'Gph',
#  'DosP',
#  'CpdB',
#  'DosP',
#  'YtjC',
#  'GpmA',
#  'GpmM',
#  'YqaB',
#  'Pgm',
#  'YbhA',
#  'PutA',
#  'SerC',
#  'AphA',
#  'SerB',
#  'RbsK',
#  'AraB',
#  'S0001',
#  'DeoD',
#  'Deleted',
#  'DeoD',
#  'PdxH',
#  'PdxK',
#  'PdxK',
#  'PdxY',
#  'PdxK',
#  'Cof',
#  'YbhA',
#  'YigL',
#  'PotD',
#  'PotB',
#  'YdcS',
#  'YdcV',
#  'PotA',
#  'PotC',
#  'YdcU',
#  'YdcT',
#  'MdtJ',
#  'MdtI',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'EntF',
#  'NudJ',
#  'IspB',
#  'RffC',
#  'RffA',
#  'RfbC',
#  'RfbD',
#  'RfbB',
#  'RffG',
#  'RhtA',
#  'RhtC',
#  'Tdk',
#  'TpiA',
#  'TrxA',
#  'TrxC',
#  'TrxB',
#  'OtsB',
#  'OtsA',
#  'TreF',
#  'TreA',
#  'TnaA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Gpt',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'SpoT',
#  'DeoB',
#  'FldB',
#  'FldA',
#  'Fpr']

# %%
z=0
increasingANDdecreasingANDstable_reactions_gene_names= list()
l= str()

while z< len(increasingANDdecreasingANDstable_reactions):

    boolean_findings = p2['Reaction'].str.contains(increasingANDdecreasingANDstable_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            increasingANDdecreasingANDstable_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

increasingANDdecreasingANDstable_reactions_gene_names
# Out:
# ['SpeA',
#  'PykA',
#  'PykF',
#  'HycC',
#  'HycG',
#  'HycE',
#  'HyfI',
#  'HycD',
#  'HycF',
#  'HyfE',
#  'HycB',
#  'HyfC',
#  'HyfJ',
#  'FdhF',
#  'HyfF',
#  'HyfG',
#  'HyfA',
#  'HyfB',
#  'HyfH',
#  'HyfD',
#  'NapG',
#  'NapA',
#  'NapC',
#  'NapB',
#  'NapH',
#  'MntH',
#  'DctA',
#  'NirB',
#  'NirD',
#  'YdjI',
#  'FbaB',
#  'FbaA',
#  'CysU',
#  'CysA',
#  'CysP',
#  'CysW',
#  'FocB',
#  'FocA']

# %%
z=0
increasingANDdecreasing_only_reactions_gene_names= list()
l= str()

while z< len(increasingANDdecreasing_only_reactions):

    boolean_findings = p2['Reaction'].str.contains(increasingANDdecreasing_only_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            increasingANDdecreasing_only_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

increasingANDdecreasing_only_reactions_gene_names
# Out:
# ['PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'OmpL',
#  'OmpG',
#  'OmpA',
#  'ZitB',
#  'FieF',
#  'AcpP',
#  'FabD',
#  'Gmm',
#  'FsaA',
#  'FsaB',
#  'S0001',
#  'YeiG',
#  'FrmB',
#  'AsnA',
#  'S0001',
#  'AqpZ',
#  'GrxB',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdF',
#  'NrdE',
#  'GldA',
#  'ZupT',
#  'GlpK',
#  'Fre',
#  'CysI',
#  'CysJ',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'PntA',
#  'PntB',
#  'IspH',
#  'PpsA',
#  'Prs',
#  'LeuA',
#  'MaeB',
#  'FdnI',
#  'FdnG',
#  'FdoI',
#  'FdnH',
#  'FdoG',
#  'FdoH',
#  'ZitB',
#  'FieF',
#  'Gmk',
#  'Gmk',
#  'ZupT',
#  'ZitB',
#  'FieF',
#  'FolK',
#  'Ppk',
#  'Adk',
#  'Ndk',
#  'Pck',
#  'Tdk',
#  'GlpX',
#  'YggF',
#  'Fbp',
#  'GalP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FocB',
#  'FocA',
#  'Gnd',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AphA',
#  'SurE',
#  'UshA',
#  'Alr',
#  'DadX',
#  'CpdB',
#  'AphA',
#  'SurE',
#  'YjjG',
#  'UshA',
#  'ZitB',
#  'FieF',
#  'DcuA',
#  'DcuB',
#  'DcuC',
#  'Deleted',
#  'DeoD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Acs',
#  'EamA',
#  'EamB',
#  'PabA',
#  'PabB',
#  'EntD',
#  'SpeE',
#  'GltA',
#  'CodA',
#  'CodB',
#  'PuuA',
#  'GlgA',
#  'ScpC',
#  'PurC',
#  'MenH',
#  'MenD',
#  'NuoC',
#  'NuoE',
#  'NuoM',
#  'NuoH',
#  'NuoF',
#  'NuoB',
#  'NuoA',
#  'NuoL',
#  'NuoG',
#  'NuoK',
#  'NuoJ',
#  'NuoN',
#  'NuoI',
#  'EamA',
#  'EamB',
#  'Adk',
#  'GrxB',
#  'TrxA',
#  'TrxC',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdA',
#  'NrdB',
#  'NrdF',
#  'NrdE',
#  'AcpP',
#  'PlsX',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'FldB',
#  'FldA',
#  'YdbK',
#  'KatE',
#  'KatG',
#  'Maa',
#  'FrlA',
#  'LysP',
#  'PuuA',
#  'GlnA',
#  'PotE',
#  'PuuP',
#  'Tmk',
#  'ThiD',
#  'SstT',
#  'CueO',
#  'GlmS',
#  'GhrB',
#  'GhrA',
#  'Ppc',
#  'Dfp',
#  'Pck',
#  'ScpC',
#  'ZupT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AraE',
#  'YdeA',
#  'Deleted',
#  'Rpe',
#  'AspC',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'AdhE',
#  'FrmA',
#  'AdhP',
#  'CitE',
#  'CitF',
#  'CitD',
#  'CitX',
#  'PrpB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'AmtB',
#  'S0001',
#  'Adk',
#  'Ndk',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'GdhA',
#  'AceB',
#  'GlcB',
#  'HyaC',
#  'HybO',
#  'HyaB',
#  'HyaA',
#  'HybA',
#  'HybB',
#  'HybC',
#  'DcuA',
#  'DcuB',
#  'DcuC',
#  'SpoT',
#  'TrkA',
#  'Kch',
#  'SapD',
#  'TrkH',
#  'Kup',
#  'TrkG',
#  'NadK',
#  'Adk',
#  'Ndk',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AdhE',
#  'MhpF',
#  'S0001',
#  'GlcD',
#  'GlcF',
#  'GlcE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DctA',
#  'DcuA',
#  'DcuB',
#  'FumB',
#  'FumC',
#  'FumA',
#  'DcuC',
#  'Tmk',
#  'ThiL',
#  'Udk',
#  'Udp',
#  'Pgi',
#  'Lpd',
#  'SucB',
#  'SucA',
#  'DdlA',
#  'DdlB',
#  'TreC',
#  'Dld',
#  'LdhA',
#  'DctA',
#  'GrxB',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdF',
#  'NrdE',
#  'CynT',
#  'Can',
#  'GrxB',
#  'TrxA',
#  'TrxC',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdA',
#  'NrdB',
#  'NrdF',
#  'NrdE',
#  'GldA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NuoC',
#  'NuoE',
#  'NuoM',
#  'NuoH',
#  'NuoF',
#  'NuoB',
#  'NuoA',
#  'NuoL',
#  'NuoG',
#  'NuoK',
#  'NuoJ',
#  'NuoN',
#  'NuoI',
#  'AccA',
#  'AccC',
#  'AccD',
#  'AccB',
#  'Deleted',
#  'DeoD',
#  'ZupT',
#  'CorA',
#  'TdcE',
#  'PflA',
#  'YfiD',
#  'PflB',
#  'PflD',
#  'PflC',
#  'DeoD',
#  'FabB',
#  'SpoT',
#  'RelA',
#  'Adk',
#  'Ndk',
#  'CorA',
#  'GlcD',
#  'GlcF',
#  'GlcE',
#  'NadD',
#  'NadR',
#  'CdsA',
#  'MpaA',
#  'Mdh',
#  'Mqo',
#  'CdsA',
#  'AcpP',
#  'PlsX',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ZupT',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'AtpC',
#  'AtpD',
#  'AtpB',
#  'AtpF',
#  'AtpE',
#  'AtpG',
#  'AtpA',
#  'AtpI',
#  'AtpH',
#  'HyaC',
#  'HybO',
#  'HyaB',
#  'HyaA',
#  'HybA',
#  'HybB',
#  'HybC',
#  'XylA',
#  'Cmk',
#  'PyrH']

# %%
Ushaped_gene_names = list( dict.fromkeys(Ushaped_gene_names) ) #remove duplicates in the list. I think that you convert it to dictionary and back to list (not sure)
one_gene_names = list( dict.fromkeys(one_gene_names) )
flat_gene_names = list( dict.fromkeys(flat_gene_names) )
saturated_gene_names = list( dict.fromkeys(saturated_gene_names) )
monotonically_increasingANDstable_reactions_gene_names = list( dict.fromkeys(monotonically_increasingANDstable_reactions_gene_names) )
monotonically_increasing_only_reactions_gene_names = list( dict.fromkeys(monotonically_increasing_only_reactions_gene_names) )
monotonically_decreasingANDstable_reactions_gene_names = list( dict.fromkeys(monotonically_decreasingANDstable_reactions_gene_names) )
monotonically_decreasing_only_reactions_gene_names = list( dict.fromkeys(monotonically_decreasing_only_reactions_gene_names) )
increasingANDdecreasingANDstable_reactions_gene_names = list( dict.fromkeys(increasingANDdecreasingANDstable_reactions_gene_names) )
increasingANDdecreasing_only_reactions_gene_names = list( dict.fromkeys(increasingANDdecreasing_only_reactions_gene_names) )

d1= pd.DataFrame(Ushaped_gene_names, columns= ["Gene names for Ushaped reactions"])
d2= pd.DataFrame(one_gene_names, columns= ["Gene names for reactions with one feasible value"])
d3= pd.DataFrame(flat_gene_names, columns= ["Gene names for flat reactions"])
d4= pd.DataFrame(saturated_gene_names, columns= ["Gene names for saturating reactions"])
d5= pd.DataFrame(monotonically_increasingANDstable_reactions_gene_names, columns= ["Gene names for increasing and stable reactions"])
d6= pd.DataFrame(monotonically_increasing_only_reactions_gene_names, columns= ["Gene names for increasing only reactions"])
d7= pd.DataFrame(monotonically_decreasingANDstable_reactions_gene_names, columns= ["Gene names for decreasing and stable reactions"])
d8= pd.DataFrame(monotonically_decreasing_only_reactions_gene_names, columns= ["Gene names for decreasing only reactions"])
d9= pd.DataFrame(increasingANDdecreasingANDstable_reactions_gene_names, columns= ["Gene names for increasing and decreasing and stable reactions"])
d10= pd.DataFrame(increasingANDdecreasing_only_reactions_gene_names, columns= ["Gene names for increasing and decreasing only reactions"])

csv_Ushaped_gene_names = d1.to_csv('Ushaped_gene_names anaerobic.csv', index = True)
csv_one_gene_names = d2.to_csv('one_gene_names anaerobic.csv', index = True) 
csv_flat_gene_names = d3.to_csv('flat_gene_names anaerobic.csv', index = True)
csv_saturated_gene_names = d4.to_csv('saturated_gene_names anaerobic.csv', index = True)
csv_monotonically_increasingANDstable_reactions_gene_names = d5.to_csv('monotonically_increasingANDstable_reactions_gene_names.csv', index = True)
csv_monotonically_increasing_only_reactions_gene_names = d6.to_csv('monotonically_increasing_only_reactions_gene_names.csv', index = True)
csv_monotonically_decreasingANDstable_reactions_gene_names = d7.to_csv('monotonically_decreasingANDstable_reactions_gene_names.csv', index = True)
csv_monotonically_decreasing_only_reactions_gene_names = d8.to_csv('monotonically_decreasing_only_reactions_gene_names.csv', index = True)
csv_increasingANDdecreasingANDstable_reactions_gene_names = d9.to_csv('increasingANDdecreasingANDstable_reactions_gene_names.csv', index = True)
csv_increasingANDdecreasing_only_reactions_gene_names = d10.to_csv('increasingANDdecreasing_only_reactions_gene_names.csv', index = True)
